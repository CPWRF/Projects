# %%
import pyodbc
from numpy import vectorize
from numpy import NaN
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.tseries.offsets import BDay
from datetime import datetime
from sqlalchemy.engine import URL
from sqlalchemy import create_engine
from UliPlot.XLSX import auto_adjust_xlsx_column_width

# %% [markdown]
# # SQL

# %%
# Get GMLA list and GMLA system date
cklist_confirm_query = """ 
SELECT [projectSizeId]
      ,[PROJECT_SIZE_NAME] as 'Project_Name'
      ,[PROJECT_CATEGORY] as 'Segment'
      ,LEFT([typeName],4) + Right([typeName],1) as 'Phase'
      ,[status]
      /*,[kickOffMeetingDate]*/
      ,[baseOverDueDate] as 'actualCloseMeetingDate'
      ,[submitDate] as 'actualGMLASubmitDate'
      /*,[IsByPass]*/
  FROM [PR_WEB2].[dbo].[T_GMLA_CKLIST_CONFIRM]

  LEFT JOIN [PR_WEB2].[dbo].[T_PS_ProdSizeRelateInfo]
  on projectSizeId = PROJECT_SIZE_ID
  /* Join project names and segment */

  LEFT JOIN [PR_WEB2].[dbo].[T_GMLA_BS_VERSION_TYPE]
  ON typeId = [PR_WEB2].[dbo].[T_GMLA_BS_VERSION_TYPE].id
  /* Join GMLA#1/#2/#3 name*/

  WHERE [IsByPass] = '0'
"""

# Get design review date which sync PM system
project_schedule_query = """ 
SELECT [ProjectSizeId] as 'projectSizeId'
      /*
      ,[PROJECT_NAME]
      ,[T_GT_ProjectSchedule].[TASK_ID]
      */
      ,[DESC_OF_TASK]
      /*
      ,[T_GT_TaskBaseInfo].[Note]
      ,[IsPM]
      */
      ,DATEADD(DAY,-21,[Current_Date]) as 'estCloseMeetingDate'
      /* Design review -21 days */
  FROM [PR_WEB2].[dbo].[T_GT_ProjectSchedule]

  LEFT JOIN [PR_WEB2].[dbo].[T_GT_TaskBaseInfo] 
  ON [T_GT_ProjectSchedule].[TASK_ID] = [T_GT_TaskBaseInfo].TASK_ID

  LEFT JOIN [PR_WEB2].[dbo].[T_PS_ProdSizeRelateInfo]
  on ProjectSizeId = [T_PS_ProdSizeRelateInfo].PROJECT_SIZE_ID
  
  WHERE DESC_OF_TASK
  IN ('Mechanical Design Review','Factory Prototype Design Review','Pilot Run Design Review')
"""

# Get OOB info in MP infomation
oob_mp_query = """
SELECT [T_MPC_CkListInfo].[PROJECT_SIZE_ID] as 'projectSizeId'
      ,[PROJECT_NAME] as 'Project_Name'
      /*,[T_MPC_CkListInfo].[MP_ID]
      ,[T_MPC_CkListInfo].[Item_ID]*/
      ,[Item_Name] as 'Description'
      ,[ORG_FILE_NAME] as 'MP_file'
      ,[Comment] as 'MP_Comment' /* User comment */
      ,[Status] /* If item is checked, 1=checked, 2=N/A */
      ,[UpdateUser]
      ,[UpdateTime]
  FROM [PR_WEB2].[dbo].[T_MPC_CkListInfo]

  LEFT JOIN [dbo].[T_PS_ProdSizeRelateInfo] 
  on [T_MPC_CkListInfo].PROJECT_SIZE_ID = [T_PS_ProdSizeRelateInfo].PROJECT_SIZE_ID

  LEFT JOIN [dbo].[T_MPC_RefFiles] on 
    [T_MPC_CkListInfo].PROJECT_SIZE_ID = [T_MPC_RefFiles].PROJECT_SIZE_ID
    AND [T_MPC_CkListInfo].MP_ID = [T_MPC_RefFiles].MP_ID
    AND [T_MPC_CkListInfo].Item_ID = [T_MPC_RefFiles].Item_ID
    /* Merge uploaded file name */

  where Item_Name like 'OOB%'
  /* Item_Name is 'Descroption' in MP information */
 
  ORDER BY [UpdateTime] DESC
"""

oob_pid_query = """
SELECT [T_PID_CkList].[PROJECT_SIZE_ID] as 'projectSizeId'
      ,[Category_Name] as 'Phase'
      ,[ORG_FILE_NAME] as 'PID_file'
      ,[COMMENT] as 'PID_Comment'
      /*,[T_PID_CkList].[MpType_ID]
      ,[T_PID_CkList].[Category_ID]
      ,[T_PID_CkList].[Item_ID]*/
      ,[Item_Name]
      ,[Status]
      ,[UpdateUser]
      ,[UpdateTime]
  FROM [PR_WEB2].[dbo].[T_PID_CkList]

  LEFT JOIN [T_PID_CkListFiles]
  ON ([T_PID_CkListFiles].[PROJECT_SIZE_ID] = [T_PID_CkList].[PROJECT_SIZE_ID]
  and [T_PID_CkListFiles].[MpType_ID] = [T_PID_CkList].[MpType_ID]
  and [T_PID_CkListFiles].[Category_ID] = [T_PID_CkList].[Category_ID]
  and [T_PID_CkListFiles].[Item_ID] = [T_PID_CkList].[Item_ID]
  and [T_PID_CkListFiles].[Frequency] = [T_PID_CkList].[Frequency]
  /* Frequency is duplicated phase count (e.g. Twice FP) */)
  where Item_Name = 'OOB planning readiness' and ORG_FILE_NAME is not NULL
"""

# %%
connection_string = "DRIVER={SQL Server};SERVER=T1-PE-SUPPORT;DATABASE=PR_WEB2;UID=pimes2;PWD=LhZEv9JtGsZNX"
connection_url = URL.create("mssql+pyodbc", query={"odbc_connect": connection_string})
engine = create_engine(connection_url)

cklist_confirm = pd.read_sql(cklist_confirm_query, engine)
project_schedule = pd.read_sql(project_schedule_query, engine, parse_dates='estCloseMeetingDate')
oob_mp = pd.read_sql(oob_mp_query, engine)
oob_pid = pd.read_sql(oob_pid_query, engine)

# %% [markdown]
# # cklist_confirm

# %%
cklist_confirm.loc[cklist_confirm.actualCloseMeetingDate.str.startswith('0001-01', na=False),'actualCloseMeetingDate'] = None

# %%
cklist_confirm.actualCloseMeetingDate = pd.to_datetime(cklist_confirm.actualCloseMeetingDate, utc=True).dt.tz_convert('Asia/Taipei')
cklist_confirm.actualGMLASubmitDate = pd.to_datetime(cklist_confirm.actualGMLASubmitDate,utc=True).dt.tz_convert('Asia/Taipei')
cklist_confirm.head()
# Out:
#    projectSizeId              Project_Name   Segment  Phase  status  \
# 0            766                    GAD 13  Aviation  GMLA1       0
# 1            766                    GAD 13  Aviation  GMLA2       0
# 2            766                    GAD 13  Aviation  GMLA3       0
# 3            909  One Battery Bike Project   Fitness  GMLA3       1
# 4            936                 Edge 1040   Fitness  GMLA1       1
#
#      actualCloseMeetingDate                actualGMLASubmitDate
# 0                       NaT                                 NaT
# 1                       NaT                                 NaT
# 2                       NaT                                 NaT
# 3 2021-02-05 00:00:00+08:00 2021-03-04 15:19:42.207827800+08:00
# 4 2021-02-05 00:00:00+08:00 2021-02-19 17:29:48.395736400+08:00

# %%
#Project id 1124 is aborted
cklist_confirm = cklist_confirm[cklist_confirm.projectSizeId != 1124]

# %% [markdown]
# Merge project_schedule

# %%
project_schedule.estCloseMeetingDate = project_schedule.estCloseMeetingDate.dt.tz_convert('Asia/Taipei')

# %%
project_schedule['Phase'] = project_schedule.DESC_OF_TASK.map(
    {'Mechanical Design Review':'GMLA1','Factory Prototype Design Review':'GMLA2','Pilot Run Design Review':'GMLA3'})
project_schedule.drop_duplicates(subset=['projectSizeId','Phase'], inplace=True)
# Some project have multi-design review date in PMsystem

# %%
overall = pd.merge(left=cklist_confirm, right=project_schedule, how='left', on=['projectSizeId','Phase'])
overall.drop('DESC_OF_TASK', axis=1, inplace=True)

# %%
def mergeCloseMeeting(actualCloseMeetingDate, estCloseMeetingDate):
    if actualCloseMeetingDate is pd.NaT:
        return estCloseMeetingDate
    else:
        return actualCloseMeetingDate
overall['mergedCloseMeetingDate'] = vectorize(mergeCloseMeeting)(overall.actualCloseMeetingDate, overall.estCloseMeetingDate)
#overall['mergedCloseMeetingDate'] = overall[['actualCloseMeetingDate','estCloseMeetingDate']].apply(lambda overall : mergeCloseMeeting(overall['actualCloseMeetingDate'], overall['estCloseMeetingDate']),axis=1)

# %%
overall.head()
# Out:
#    projectSizeId              Project_Name   Segment  Phase  status  \
# 0            766                    GAD 13  Aviation  GMLA1       0
# 1            766                    GAD 13  Aviation  GMLA2       0
# 2            766                    GAD 13  Aviation  GMLA3       0
# 3            909  One Battery Bike Project   Fitness  GMLA3       1
# 4            936                 Edge 1040   Fitness  GMLA1       1
#
#      actualCloseMeetingDate                actualGMLASubmitDate  \
# 0                       NaT                                 NaT
# 1                       NaT                                 NaT
# 2                       NaT                                 NaT
# 3 2021-02-05 00:00:00+08:00 2021-03-04 15:19:42.207827800+08:00
# 4 2021-02-05 00:00:00+08:00 2021-02-19 17:29:48.395736400+08:00
#
#         estCloseMeetingDate    mergedCloseMeetingDate
# 0                       NaT                       NaT
# 1                       NaT                       NaT
# 2                       NaT                       NaT
# 3 2021-07-13 00:00:00+08:00 2021-02-05 00:00:00+08:00
# 4 2020-10-13 00:00:00+08:00 2021-02-05 00:00:00+08:00

# %%
overall['targetGMLASubmitDate'] = (overall.mergedCloseMeetingDate + BDay(8)).dt.date
overall.iloc[:,5:] = overall.iloc[:,5:].apply(lambda time: pd.to_datetime(time).dt.date)
overall.status = overall.status.map({1:'Complete',0:'Incomplete'})

# %%
overall.drop(['actualCloseMeetingDate','estCloseMeetingDate','mergedCloseMeetingDate'],axis=1, inplace=True)

# %%
overall.head()
# Out:
#    projectSizeId              Project_Name   Segment  Phase      status  \
# 0            766                    GAD 13  Aviation  GMLA1  Incomplete
# 1            766                    GAD 13  Aviation  GMLA2  Incomplete
# 2            766                    GAD 13  Aviation  GMLA3  Incomplete
# 3            909  One Battery Bike Project   Fitness  GMLA3    Complete
# 4            936                 Edge 1040   Fitness  GMLA1    Complete
#
#   actualGMLASubmitDate targetGMLASubmitDate
# 0                  NaT                  NaT
# 1                  NaT                  NaT
# 2                  NaT                  NaT
# 3           2021-03-04           2021-02-17
# 4           2021-02-19           2021-02-17

# %% [markdown]
# # OOB from MP infomation

# %% [markdown]
# Merge comment from oob_mp

# %%
oob_mp_group = oob_mp.groupby(['projectSizeId','Project_Name'])['MP_file'].count().to_frame().reset_index()
oob_mp_group.rename(columns={'MP_file':'MP_file_count'},inplace=True)
oob_mp_group.head()
# Out:
#    projectSizeId         Project_Name  MP_file_count
# 0            766               GAD 13              0
# 1            767  OnDeck (Telematics)              0
# 2            768   USB SD-Card Reader              0
# 3            769         Striker Cast              0
# 4            770      Rally XC200/100              0

# %% [markdown]
# Merge OOB from MP to overall

# %%
overall_oob_mp = pd.merge(left=overall, right=oob_mp_group, how='left',left_on=['projectSizeId','Project_Name'], right_on=['projectSizeId','Project_Name'])
overall_oob_mp.head()
# Out:
#    projectSizeId              Project_Name   Segment  Phase      status  \
# 0            766                    GAD 13  Aviation  GMLA1  Incomplete
# 1            766                    GAD 13  Aviation  GMLA2  Incomplete
# 2            766                    GAD 13  Aviation  GMLA3  Incomplete
# 3            909  One Battery Bike Project   Fitness  GMLA3    Complete
# 4            936                 Edge 1040   Fitness  GMLA1    Complete
#
#   actualGMLASubmitDate targetGMLASubmitDate  MP_file_count
# 0                  NaT                  NaT            0.0
# 1                  NaT                  NaT            0.0
# 2                  NaT                  NaT            0.0
# 3           2021-03-04           2021-02-17            0.0
# 4           2021-02-19           2021-02-17            0.0

# %% [markdown]
# Merge comment from oob_mp to overall_oob_mp

# %%
oob_mp['MP_Comment'] = oob_mp['MP_Comment'].str.replace('</p>','').str.replace('<p>','').str.replace('\n','').str.replace('&nbsp;','')
# oob_mp['MP_Comment'] = oob_mp['MP_Comment'].str.replace('<p>','')
# oob_mp['MP_Comment'] = oob_mp['MP_Comment'].str.replace('\n','')

# %%
#Merge comment from oob_mp. Need to drop_duplicates since multi-files can be uploaded but one comment only
overall_oob_mp = pd.merge(left=overall_oob_mp, right=oob_mp[['projectSizeId','MP_Comment']].drop_duplicates(),left_on=['projectSizeId'], right_on=['projectSizeId'], how='left')

# %%
overall_oob_mp[overall_oob_mp.Project_Name == 'EPIX PRO (Gen 2) 51mm']
# Out:
#      projectSizeId           Project_Name  Segment  Phase    status  \
# 644           1094  EPIX PRO (Gen 2) 51mm  Outdoor  GMLA1  Complete
# 645           1094  EPIX PRO (Gen 2) 51mm  Outdoor  GMLA2  Complete
# 646           1094  EPIX PRO (Gen 2) 51mm  Outdoor  GMLA3  Complete
#
#     actualGMLASubmitDate targetGMLASubmitDate  MP_file_count  \
# 644           2022-07-22           2022-07-22            2.0
# 645           2022-11-07           2022-11-07            2.0
# 646           2023-02-17           2023-02-23            2.0
#
#                     MP_Comment
# 644  ALS, AOD, ECG, Flashlight
# 645  ALS, AOD, ECG, Flashlight
# 646  ALS, AOD, ECG, Flashlight

# %% [markdown]
# # OOB from PID checklist

# %%
oob_pid.Phase = oob_pid.Phase.map({'Factory Prototype Close':'GMLA2','Pilot Run Close':'GMLA3'})

# %%
oob_pid.sort_values(['projectSizeId','UpdateTime'], ascending=True, inplace=True)

# %% [markdown]
# Merge OOB from PID to overall

# %%
oob_pid_group = oob_pid.groupby(['projectSizeId','Phase'])['PID_file'].count().to_frame().reset_index()
oob_pid_group.rename(columns={'PID_file':'PID_file_count'}, inplace=True)
oob_pid_group.head()
# Out:
#    projectSizeId  Phase  PID_file_count
# 0            961  GMLA2               2
# 1            962  GMLA2               2
# 2           1018  GMLA3               2
# 3           1036  GMLA2               2
# 4           1041  GMLA3               2

# %% [markdown]
# Merge comment from oob_pid

# %%
oob_pid.PID_Comment = oob_pid.PID_Comment.str.replace('</p>','').str.replace('<p>','').str.replace('\n','').str.replace('&nbsp;','')

# %%
overall_oob_mp_pid = pd.merge(left=overall_oob_mp, right=oob_pid_group, how='left',left_on=['projectSizeId','Phase'], right_on=['projectSizeId','Phase']).sort_values('actualGMLASubmitDate', ascending=True)
#Merge comment from oob_pid. Need to drop_duplicates since multi-files can be uploaded but one comment only
overall_oob_mp_pid = pd.merge(left=overall_oob_mp_pid, right=oob_pid[['projectSizeId','Phase','PID_Comment']].drop_duplicates(), how='left',left_on=['projectSizeId','Phase'], right_on=['projectSizeId','Phase'])

overall_oob_mp_pid = overall_oob_mp_pid[overall_oob_mp_pid.Phase.isin(['GMLA2','GMLA3'])]
overall_oob_mp_pid = overall_oob_mp_pid[~overall_oob_mp_pid.Segment.isin(['OEM Auto','Aviation'])]

# %%
overall_oob_mp_pid.MP_file_count.fillna(0, inplace=True)
overall_oob_mp_pid.PID_file_count.fillna(0, inplace=True)
overall_oob_mp_pid['PID+MP_count'] = (overall_oob_mp_pid.MP_file_count + overall_oob_mp_pid.PID_file_count)

# %%
overall_oob_mp_pid.head()
# Out:
#    projectSizeId            Project_Name     Segment  Phase    status  \
# 0            970            Approach G12     Outdoor  GMLA2  Complete
# 1            959                fenix 7S     Outdoor  GMLA2  Complete
# 2            870      Forerunner 945 LTE     Fitness  GMLA3  Complete
# 3            954         Dash Cam Mini 2  Automotive  GMLA3  Complete
# 4            917  Dash Cam 47 / 57 / 67W  Automotive  GMLA3  Complete
#
#   actualGMLASubmitDate targetGMLASubmitDate  MP_file_count MP_Comment  \
# 0           2020-12-25           2020-12-31            0.0
# 1           2020-12-28           2021-01-04            0.0
# 2           2020-12-28           2020-12-28            0.0
# 3           2020-12-28           2020-12-21            0.0
# 4           2020-12-28           2020-12-24            0.0
#
#    PID_file_count PID_Comment  PID+MP_count
# 0             0.0         NaN           0.0
# 1             0.0         NaN           0.0
# 2             0.0         NaN           0.0
# 3             0.0         NaN           0.0
# 4             0.0         NaN           0.0

# %%
# GMLA2 should upload 1 or more files; GMLA3 should 2 or more
def judgement(phase, totalCount):
    if (phase == 'GMLA2') & (totalCount >= 1):
        return True
    elif (phase == 'GMLA3') & (totalCount >= 2):
        return True
    else:
        return False

# %%
overall_oob_mp_pid['judgement'] = vectorize(judgement)(overall_oob_mp_pid['Phase'],overall_oob_mp_pid['PID+MP_count'])

# %%
def comment(MP, PID):
    if (MP is not NaN) & (PID is NaN):
        return MP
    elif (MP is NaN) & (PID is not NaN):
        return PID
    elif (MP is NaN) & (PID is NaN):
        return NaN
overall_oob_mp_pid['Comment'] = vectorize(comment)(overall_oob_mp_pid.MP_Comment, overall_oob_mp_pid.PID_Comment)

# %% [markdown]
# # New feature

# %%
feature = overall_oob_mp_pid[['Project_Name','actualGMLASubmitDate','Comment']].copy()

# %%
def tweak_feature(feature):
    return(feature
    .assign(actualGMLASubmitDate = pd.to_datetime(feature.actualGMLASubmitDate))
    .query("actualGMLASubmitDate > '2022-10-01'")
    )

# %%
comment = feature.Comment.str.replace(' ','').str.split(',',expand=True)
feature_comment = pd.merge(left=tweak_feature(feature), right=comment, left_on=tweak_feature(feature).index, right_on=comment.index).drop(['Comment','key_0'],axis=1)

# %%
def tweak_feature_comment(feature_comment):
    return(feature_comment
    .assign(actualGMLASubmitDate = feature_comment.actualGMLASubmitDate.dt.to_period('D'))
    )
tweak_feature_comment(feature_comment)
# Out:
#                               Project_Name actualGMLASubmitDate  \
# 0          vivomove Trend (previously "4")           2022-10-14
# 1                          BlueNet Gateway           2022-10-20
# 2                           BlueNet Switch           2022-10-20
# 3                    EPIX PRO (Gen 2) 42mm           2022-10-24
# 4                    EPIX PRO (Gen 2) 47mm           2022-10-31
# 5                         Foretrex 801/901           2022-11-03
# 6   Varia eBike Radar Tail Light (eRTL615)           2022-11-03
# 7                    EPIX PRO (Gen 2) 51mm           2022-11-07
# 8                                 eTrex SE           2022-11-08
# 9                                Serv - 7"           2022-11-10
# 10                             Serv  - 10"           2022-11-10
# 11                                zumo XT2           2022-11-15
# 12                     fenix 7S Pro (2022)           2022-11-21
# 13                             fenix 7 Pro           2022-11-21
# 14                  Panoptix PS70 - (SSMB)           2022-11-28
# 15                 ECHOMAP UHD2 (Touch) 9"           2022-11-28
# 16                 ECHOMAP UHD2 (Touch) 7"           2022-11-28
# 17                 ECHOMAP UHD2 (Touch) 6"           2022-11-28
# 18                            fenix 7X Pro           2022-12-01
# 19                                Drive 53           2022-12-01
# 20                            Edge 540 840           2022-12-08
# 21          GMR xHD3 Magnetron Open Arrays           2022-12-09
# 22                         Forerunner 265s           2022-12-13
# 23                          Forerunner 265           2022-12-13
# 24                          Forerunner 965           2022-12-15
# 25                       Instinct 2X Solar           2022-12-31
# 26                                zumo XT2           2023-01-10
# 27  Varia eBike Radar Tail Light (eRTL615)           2023-01-31
# 28                                 Venu 3S           2023-01-31
# 29                       Instinct 2X Solar           2023-02-01
# 30   GMR xHD3 Domes (18/24xHD replacement)           2023-02-02
# 31                                  Venu 3           2023-02-06
# 32                        Alpha Dog Collar           2023-02-10
# 33                        Foretrex 801/901           2023-02-12
# 34                           Approach S70s           2023-02-15
# 35                            Approach S70           2023-02-15
# 36                   EPIX PRO (Gen 2) 51mm           2023-02-17
# 37                   EPIX PRO (Gen 2) 47mm           2023-02-22
# 38                   EPIX PRO (Gen 2) 42mm           2023-02-23
# 39                               Serv - 7"           2023-03-13
# 40                             Serv  - 10"           2023-03-13
# 41            Force Kraken Trolling Motor            2023-03-15
# 42                       GPSMAP 9000 - 19"           2023-03-16
# 43                             fenix 7 Pro           2023-03-21
# 44                     fenix 7S Pro (2022)           2023-03-22
# 45                            Approach S70           2023-03-28
# 46                           Approach S70s           2023-03-28
# 47                            fenix 7X Pro           2023-03-29
# 48                          BlueNet Switch           2023-04-06
# 49                  Catalyst KMR - Display           2023-04-06
# 50                      Catalyst KMR - Hub           2023-04-06
# 51                         BlueNet Gateway           2023-04-06
# 52                   Catalyst KMR - Camera           2023-04-06
# 53                            vivoactive 5           2023-04-10
#
#                       0                1                2           3     4
# 0                  None             None             None        None  None
# 1                   LED             None             None        None  None
# 2                   LED             None             None        None  None
# 3                   ALS              AOD              ECG  Flashlight  None
# 4                   ALS              AOD              ECG  Flashlight  None
# 5                  None             None             None        None  None
# 6                  None             None             None        None  None
# 7                   ALS              AOD              ECG  Flashlight  None
# 8                  None             None             None        None  None
# 9                  None             None             None        None  None
# 10                 None             None             None        None  None
# 11                 None             None             None        None  None
# 12                  ECG       Flashlight             None        None  None
# 13                  ECG       Flashlight             None        None  None
# 14           Appearance             None             None        None  None
# 15                 None             None             None        None  None
# 16                 None             None             None        None  None
# 17                 None             None             None        None  None
# 18                  ECG             None             None        None  None
# 19                 None             None             None        None  None
# 20                 None             None             None        None  None
# 21                 None             None             None        None  None
# 22                 None             None             None        None  None
# 23                 None             None             None        None  None
# 24                 None             None             None        None  None
# 25           Flashlight             None             None        None  None
# 26                 None             None             None        None  None
# 27                 None             None             None        None  None
# 28      Voiceassistance              ECG  Skintemperature         ALS   AOD
# 29           Flashlight             None             None        None  None
# 30                 None             None             None        None  None
# 31      Voiceassistance              ECG  Skintemperature         ALS   AOD
# 32  Paringwithalpha300i             None             None        None  None
# 33                 None             None             None        None  None
# 34                  ALS              AOD             WiFi    Workouts  None
# 35                  ALS              AOD             WiFi    Workouts  None
# 36                  ALS              AOD              ECG  Flashlight  None
# 37                  ALS              AOD              ECG  Flashlight  None
# 38                  ALS              AOD              ECG  Flashlight  None
# 39                 None             None             None        None  None
# 40                 None             None             None        None  None
# 41                  nan             None             None        None  None
# 42                 WiFi  Voiceassistance             None        None  None
# 43                  ECG       Flashlight             None        None  None
# 44                  ECG       Flashlight             None        None  None
# 45                  nan             None             None        None  None
# 46                  nan             None             None        None  None
# 47                  ECG             None             None        None  None
# 48                  nan             None             None        None  None
# 49                  nan             None             None        None  None
# 50                  nan             None             None        None  None
# 51                  nan             None             None        None  None
# 52                  nan             None             None        None  None
# 53                  nan             None             None        None  None

# %%
def SumProject(feature):
    return(tweak_feature(feature)
    .assign(actualGMLASubmitDate = tweak_feature(feature).actualGMLASubmitDate.dt.to_period('M'))
    .rename(columns={"Project_Name": "Project_sum"})
    .groupby(['actualGMLASubmitDate'])
    ['Project_sum']
    .count()
    .to_frame()
    .astype('int8')
    .transpose()
    )
SumProject(feature)
# Out:
# actualGMLASubmitDate  2022-10  2022-11  2022-12  2023-01  2023-02  2023-03  \
# Project_sum                 5       13        8        3       10        9
#
# actualGMLASubmitDate  2023-04
# Project_sum                 6

# %%
def metrix_feature(feature_comment):
    return(feature_comment
    .melt(id_vars=['Project_Name','actualGMLASubmitDate'],value_vars=[0,1,2,3],value_name='New_feature')
    .drop('variable',axis=1)
    .assign(actualGMLASubmitDate = lambda df : df.actualGMLASubmitDate.dt.to_period('M'))
    .groupby(['New_feature','actualGMLASubmitDate'])
    .count()
    .unstack(level='actualGMLASubmitDate')
    ['Project_Name']
    .fillna(0)
    # .drop(index='',axis=0)
    # .drop(index='nan',axis=0)
    .astype('int8')
    .pipe(lambda df : pd.concat([df,SumProject(feature)],axis=0))
    .pipe(lambda df : df.style.background_gradient(subset=pd.IndexSlice[df.index[:-1],:],axis=None))
    )
metrix_feature(feature_comment)
# Out:
# <style type="text/css">
# #T_2f7ef_row0_col0, #T_2f7ef_row1_col0, #T_2f7ef_row3_col0, #T_2f7ef_row4_col0, #T_2f7ef_row4_col5, #T_2f7ef_row5_col0, #T_2f7ef_row6_col3, #T_2f7ef_row6_col4, #T_2f7ef_row6_col5, #T_2f7ef_row10_col4, #T_2f7ef_row11_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_2f7ef_row0_col1, #T_2f7ef_row0_col3, #T_2f7ef_row1_col1, #T_2f7ef_row2_col1, #T_2f7ef_row3_col2, #T_2f7ef_row3_col3, #T_2f7ef_row4_col2, #T_2f7ef_row6_col0, #T_2f7ef_row7_col4, #T_2f7ef_row8_col3, #T_2f7ef_row8_col4, #T_2f7ef_row9_col3, #T_2f7ef_row9_col4, #T_2f7ef_row9_col5, #T_2f7ef_row10_col5 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_2f7ef_row0_col2, #T_2f7ef_row0_col5, #T_2f7ef_row0_col6, #T_2f7ef_row1_col2, #T_2f7ef_row1_col3, #T_2f7ef_row1_col5, #T_2f7ef_row1_col6, #T_2f7ef_row2_col0, #T_2f7ef_row2_col2, #T_2f7ef_row2_col3, #T_2f7ef_row2_col4, #T_2f7ef_row2_col5, #T_2f7ef_row2_col6, #T_2f7ef_row3_col6, #T_2f7ef_row4_col3, #T_2f7ef_row4_col6, #T_2f7ef_row5_col1, #T_2f7ef_row5_col2, #T_2f7ef_row5_col3, #T_2f7ef_row5_col4, #T_2f7ef_row5_col5, #T_2f7ef_row5_col6, #T_2f7ef_row6_col6, #T_2f7ef_row7_col0, #T_2f7ef_row7_col1, #T_2f7ef_row7_col2, #T_2f7ef_row7_col3, #T_2f7ef_row7_col5, #T_2f7ef_row7_col6, #T_2f7ef_row8_col0, #T_2f7ef_row8_col1, #T_2f7ef_row8_col2, #T_2f7ef_row8_col5, #T_2f7ef_row8_col6, #T_2f7ef_row9_col0, #T_2f7ef_row9_col1, #T_2f7ef_row9_col2, #T_2f7ef_row9_col6, #T_2f7ef_row10_col0, #T_2f7ef_row10_col1, #T_2f7ef_row10_col2, #T_2f7ef_row10_col3, #T_2f7ef_row10_col6, #T_2f7ef_row11_col0, #T_2f7ef_row11_col1, #T_2f7ef_row11_col2, #T_2f7ef_row11_col3, #T_2f7ef_row11_col5, #T_2f7ef_row11_col6, #T_2f7ef_row12_col0, #T_2f7ef_row12_col1, #T_2f7ef_row12_col2, #T_2f7ef_row12_col3, #T_2f7ef_row12_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2f7ef_row0_col4, #T_2f7ef_row6_col2, #T_2f7ef_row12_col6 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_2f7ef_row1_col4 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_2f7ef_row3_col1, #T_2f7ef_row3_col5, #T_2f7ef_row4_col1, #T_2f7ef_row12_col5 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_2f7ef_row3_col4, #T_2f7ef_row4_col4 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_2f7ef_row6_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2f7ef">
#   <thead>
#     <tr>
#       <th class="index_name level0" >actualGMLASubmitDate</th>
#       <th id="T_2f7ef_level0_col0" class="col_heading level0 col0" >2022-10</th>
#       <th id="T_2f7ef_level0_col1" class="col_heading level0 col1" >2022-11</th>
#       <th id="T_2f7ef_level0_col2" class="col_heading level0 col2" >2022-12</th>
#       <th id="T_2f7ef_level0_col3" class="col_heading level0 col3" >2023-01</th>
#       <th id="T_2f7ef_level0_col4" class="col_heading level0 col4" >2023-02</th>
#       <th id="T_2f7ef_level0_col5" class="col_heading level0 col5" >2023-03</th>
#       <th id="T_2f7ef_level0_col6" class="col_heading level0 col6" >2023-04</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f7ef_level0_row0" class="row_heading level0 row0" >ALS</th>
#       <td id="T_2f7ef_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_2f7ef_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_2f7ef_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_2f7ef_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_2f7ef_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_2f7ef_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_2f7ef_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f7ef_level0_row1" class="row_heading level0 row1" >AOD</th>
#       <td id="T_2f7ef_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_2f7ef_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_2f7ef_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_2f7ef_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_2f7ef_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_2f7ef_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_2f7ef_row1_col6" class="data row1 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f7ef_level0_row2" class="row_heading level0 row2" >Appearance</th>
#       <td id="T_2f7ef_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_2f7ef_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_2f7ef_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_2f7ef_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_2f7ef_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_2f7ef_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_2f7ef_row2_col6" class="data row2 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f7ef_level0_row3" class="row_heading level0 row3" >ECG</th>
#       <td id="T_2f7ef_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_2f7ef_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_2f7ef_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_2f7ef_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_2f7ef_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_2f7ef_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_2f7ef_row3_col6" class="data row3 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f7ef_level0_row4" class="row_heading level0 row4" >Flashlight</th>
#       <td id="T_2f7ef_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_2f7ef_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_2f7ef_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_2f7ef_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_2f7ef_row4_col4" class="data row4 col4" >4</td>
#       <td id="T_2f7ef_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_2f7ef_row4_col6" class="data row4 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f7ef_level0_row5" class="row_heading level0 row5" >LED</th>
#       <td id="T_2f7ef_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_2f7ef_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_2f7ef_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_2f7ef_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_2f7ef_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_2f7ef_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_2f7ef_row5_col6" class="data row5 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f7ef_level0_row6" class="row_heading level0 row6" >None</th>
#       <td id="T_2f7ef_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_2f7ef_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_2f7ef_row6_col2" class="data row6 col2" >6</td>
#       <td id="T_2f7ef_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_2f7ef_row6_col4" class="data row6 col4" >2</td>
#       <td id="T_2f7ef_row6_col5" class="data row6 col5" >2</td>
#       <td id="T_2f7ef_row6_col6" class="data row6 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f7ef_level0_row7" class="row_heading level0 row7" >Paringwithalpha300i</th>
#       <td id="T_2f7ef_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_2f7ef_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_2f7ef_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_2f7ef_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_2f7ef_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_2f7ef_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_2f7ef_row7_col6" class="data row7 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f7ef_level0_row8" class="row_heading level0 row8" >Skintemperature</th>
#       <td id="T_2f7ef_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_2f7ef_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_2f7ef_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_2f7ef_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_2f7ef_row8_col4" class="data row8 col4" >1</td>
#       <td id="T_2f7ef_row8_col5" class="data row8 col5" >0</td>
#       <td id="T_2f7ef_row8_col6" class="data row8 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f7ef_level0_row9" class="row_heading level0 row9" >Voiceassi

# %% [markdown]
# # Excel writer

# %%
with pd.ExcelWriter('OOB_tracking.xlsx',engine='openpyxl') as writer:
    
    metrix_feature(feature_comment).to_excel(writer, sheet_name='feature_metrix')

    tweak_feature_comment(feature_comment).to_excel(writer, sheet_name='feature_comment', index=False)

    overall_oob_mp_pid.to_excel(writer, sheet_name='overall_oob_mp_pid',index=False)
    auto_adjust_xlsx_column_width(overall_oob_mp_pid, writer, sheet_name="overall_oob_mp_pid", margin=5)

    oob_mp.to_excel(writer, sheet_name='oob_mp',index=False)
    auto_adjust_xlsx_column_width(oob_mp, writer, sheet_name="oob_mp", margin=5)

    oob_pid.to_excel(writer, sheet_name='oob_pid',index=False)
    auto_adjust_xlsx_column_width(oob_pid, writer, sheet_name="oob_pid", margin=5)
