# %%
import pandas as pd
import manufacturing as mn
import matplotlib.pyplot as plt

# %%
raw = pd.read_excel('T1_torque.xlsx')

# %%
low, upper = mn.suggest_specification_limits(raw.torque)

# %%
low
# Out:
# 0.6250146536985224

# %%
upper
# Out:
# 0.7593603463014775

# %%
mn.ppk_plot(data=raw.torque, lower_specification_limit=low, upper_specification_limit=upper)
plt.show()
