# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os import getcwd
from UliPlot.XLSX import auto_adjust_xlsx_column_width
from datetime import datetime

# %%
pmsystem_project_list_file = '(Input) ProjectListExport.xls'
cft_list_file = '(Input) CFTListExport.xls'
prweb_file = '(Input) New Production Status Summary.xlsx'

start_from = '2022-05'

consumer_dpqe_list = ['Lo, Aalto','Kuo, Chris','Wang, Cooper', 'Fu, Ernest','Hsu, Jason(PQE)','Ni, Wendy','Wang, Evelyn','Hsu, Jason(PQE);\nWang, Evelyn'] 
# 'Hsu, Jason(PQE);\nWang, Evelyn' is for GPSMAP 9000 series

# %% [markdown]
# # PM system

# %% [markdown]
# Read

# %%
pmsystem_project = pd.read_excel(pmsystem_project_list_file, usecols=[0,1,3,4,5,6,9,10,12], parse_dates=[2,3,4,5], index_col=[0])
pmsystem_cft = pd.read_excel(cft_list_file, usecols=[0,44], index_col=[0])
# Out:
# c:\Users\wangcooper\Miniconda3\envs\workspace\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
pmsystem_cft.head()
# Out:
#            Develop  Product QE (DPQE)
# Project ID
# 15624                       Lo, Aalto
# 13009                      Kuo, Chris
# 14984                      Kuo, Chris
# 16199                       Ni, Wendy
# 16547                             NaN

# %%
pmsystem_project = pmsystem_project[(pmsystem_project['PDP/Form107'] == 'PDP')]

# %%
pmsystem_project.head()
# Out:
#                                   Project Name  \
# Project ID
# 15624              Catalyst Kart/Moto/Roadster
# 13009                      Dash Cam Live (LTE)
# 14984                Dash Cam Live (LTE), ASIA
# 16199             DC-2023 Premium Dash Cameras
# 16547       DC-2023 Premium Dash Cameras, Asia
#
#            Working Prototype Built and Tested Final Factory Prototypes Built  \
# Project ID
# 15624                              2022-06-24                            NaT
# 13009                              2021-06-25                     2022-03-11
# 14984                                     NaT                     2022-03-31
# 16199                              2022-12-22                     2023-05-10
# 16547                                     NaT                            NaT
#
#               MP Date    PR Date Global/Asia PDP/Form107       Status
# Project ID
# 15624      2023-03-20 2023-01-09      Global         PDP  Development
# 13009      2022-10-24 2022-08-24      Global         PDP  Development
# 14984      2022-11-07 2022-10-17        Asia         PDP  Development
# 16199      2023-07-31 2023-05-31      Global         PDP  Development
# 16547             NaT        NaT        Asia         PDP  Development

# %% [markdown]
# Merge project and CFT lists

# %%
pmsystem_project_cft = pd.merge(left=pmsystem_project, right=pmsystem_cft, left_index=True, right_index=True)
pmsystem_project_cft.sort_index().head()
# Out:
#                             Project Name Working Prototype Built and Tested  \
# Project ID
# 2854                  Product - GDC 7500                         2013-04-30
# 2914               Product - GTN 6xx/7xx                                NaT
# 2930                  Product - GWX 7000                         2019-03-22
# 3753                   Product - GDU 7XX                         2015-08-14
# 3767        HIRF & Lightning System Cert                                NaT
#
#            Final Factory Prototypes Built    MP Date    PR Date Global/Asia  \
# Project ID
# 2854                                  NaT 2019-07-01 2018-10-12      Global
# 2914                                  NaT        NaT        NaT      Global
# 2930                                  NaT 2021-09-09 2021-06-04      Global
# 3753                                  NaT 2018-01-26 2017-01-05      Global
# 3767                                  NaT        NaT        NaT      Global
#
#            PDP/Form107       Status Develop  Product QE (DPQE)
# Project ID
# 2854               PDP  Development                 Kuo, Chris
# 2914               PDP  Development                        NaN
# 2930               PDP     Concepts                        NaN
# 3753               PDP  Development                        NaN
# 3767               PDP  Development                        NaN

# %% [markdown]
# Find projects which WW/ASIA SKU have different DPQE

# %%
ww_asia_diff = pmsystem_project_cft.copy()

# %%
#Handle Asis words in 'Project Name' column
ww_asia_diff['Project Name'] = ww_asia_diff['Project Name'].apply(lambda name : name.split(',')[0])
ww_asia_diff['Project Name'] = ww_asia_diff['Project Name'].str.replace('ASIA','')
ww_asia_diff['Project Name'] = ww_asia_diff['Project Name'].str.replace('Asia','')

# %%
# check any missing
ww_asia_diff[ww_asia_diff['Project Name'].str.contains('ASIA|asia|Asia')]
# Out:
# Empty DataFrame
# Columns: [Project Name, Working Prototype Built and Tested, Final Factory Prototypes Built, MP Date, PR Date, Global/Asia, PDP/Form107, Status, Develop  Product QE (DPQE)]
# Index: []

# %%
ww_asia_diff = ww_asia_diff[['Project Name','Develop  Product QE (DPQE)','Global/Asia','MP Date']].loc[ww_asia_diff['MP Date']> start_from]

# %%
# Find duplicated projects
ww_asia_diff = ww_asia_diff[ww_asia_diff.duplicated(subset=['Project Name'],keep=False)]
ww_asia_diff
# Out:
#                    Project Name Develop  Product QE (DPQE) Global/Asia  \
# Project ID
# 13009       Dash Cam Live (LTE)                 Kuo, Chris      Global
# 14984       Dash Cam Live (LTE)                 Kuo, Chris        Asia
# 14994            Edge Explore 2                 Kuo, Chris      Global
# 16259            Edge Explore 2                 Kuo, Chris        Asia
# 15993                    Lily 2                 Fu, Ernest      Global
# 16414                    Lily 2                 Fu, Ernest        Asia
# 15520                    Venu 3               Wang, Cooper      Global
# 16260                    Venu 3               Wang, Cooper        Asia
# 15519                   Venu 3S                 Fu, Ernest      Global
# 16261                   Venu 3S                 Fu, Ernest        Asia
# 14949                 Venu Sq 2                  Lo, Aalto      Global
# 15827                 Venu Sq 2                  Lo, Aalto        Asia
# 14004            vivomove Trend                  Lo, Aalto      Global
# 15505            vivomove Trend                  Lo, Aalto        Asia
# 16176              Approach S70               Wang, Cooper      Global
# 16190              Approach S70               Wang, Cooper        Asia
# 12705              Approach Z50                 Kuo, Chris      Global
# 13920              Approach Z50                 Kuo, Chris        Asia
# 12994               Descent Mk3               Wang, Cooper      Global
# 16074               Descent Mk3               Wang, Cooper        Asia
# 16205              Descent Mk3s               Wang, Cooper      Global
# 16231              Descent Mk3s               Wang, Cooper        Asia
# 12799           Descent S1 Buoy                  Lo, Aalto      Global
# 14069           Descent S1 Buoy                  Lo, Aalto        Asia
# 15843                  eTrex SE                 Kuo, Chris      Global
# 16023                  eTrex SE                 Kuo, Chris        Asia
# 10901               eTrex Solar                 Kuo, Chris      Global
# 16157               eTrex Solar                 Kuo, Chris        Asia
# 14539         inReach Messenger                 Kuo, Chris      Global
# 15917         inReach Messenger                 Kuo, Chris        Asia
# 13084        Instinct Crossover                  Lo, Aalto      Global
# 15828        Instinct Crossover                  Lo, Aalto        Asia
#
#               MP Date
# Project ID
# 13009      2022-10-24
# 14984      2022-11-07
# 14994      2022-05-30
# 16259      2022-07-25
# 15993      2023-10-30
# 16414      2023-10-16
# 15520      2023-05-29
# 16260      2023-05-29
# 15519      2023-05-29
# 16261      2023-05-29
# 14949      2022-08-01
# 15827      2022-08-12
# 14004      2022-11-14
# 15505      2022-11-21
# 16176      2023-03-20
# 16190      2023-04-10
# 12705      2023-05-01
# 13920      2023-05-01
# 12994      2023-10-02
# 16074      2023-10-30
# 16205      2023-09-18
# 16231      2023-10-16
# 12799      2023-07-31
# 14069      2023-04-24
# 15843      2022-11-28
# 16023      2023-09-18
# 10901      2023-08-21
# 16157      2023-12-18
# 14539      2022-07-25
# 15917      2022-12-19
# 13084      2022-10-11
# 15828      2022-10-11

# %%
# Find projects have different DPQE
ww_asia_diff_DPQE = ww_asia_diff[~ww_asia_diff.duplicated(subset=['Project Name','Develop  Product QE (DPQE)'],keep=False)]

# %% [markdown]
# Find projects w/o DPQE (include ASIA SKUs)

# %%
projects_wo_DPQE = pmsystem_project_cft[pmsystem_project_cft['Develop  Product QE (DPQE)'].isnull()].dropna(thresh=5, axis=0).loc[(pmsystem_project_cft['MP Date']>start_from)]

# %% [markdown]
# Find projects with multi-DPQE (include ASIA SKUs)

# %%
multi_dpqe = pmsystem_project_cft[['Project Name','Global/Asia','Develop  Product QE (DPQE)','MP Date']]
multi_dpqe = multi_dpqe[multi_dpqe['MP Date']>start_from]
multi_dpqe.dropna(inplace=True)

# %%
multi_dpqe = multi_dpqe[multi_dpqe['Develop  Product QE (DPQE)'].str.contains('\n')]

# %% [markdown]
# Melt

# %%
df_consumer_dpqe = pmsystem_project_cft[pmsystem_project_cft['Develop  Product QE (DPQE)'].isin(consumer_dpqe_list)].sort_index()
df_consumer_dpqe = df_consumer_dpqe[df_consumer_dpqe['Global/Asia']=='Global']
df_consumer_dpqe.head()
# Out:
#                                Project Name  \
# Project ID
# 2854                     Product - GDC 7500
# 5711                       Product - GLA 85
# 7011        Xero G2i SatCom Scouting Camera
# 7029                       Alpha Dog Collar
# 7563                                Mercury
#
#            Working Prototype Built and Tested Final Factory Prototypes Built  \
# Project ID
# 2854                               2013-04-30                            NaT
# 5711                               2014-10-30                            NaT
# 7011                               2020-03-03                     2020-11-09
# 7029                               2021-11-18                     2022-08-18
# 7563                                      NaT                            NaT
#
#               MP Date    PR Date Global/Asia PDP/Form107       Status  \
# Project ID
# 2854       2019-07-01 2018-10-12      Global         PDP  Development
# 5711       2018-12-07 2016-08-31      Global         PDP  Development
# 7011              NaT 2021-08-27      Global         PDP  Development
# 7029       2023-01-03 2022-10-28      Global         PDP  Development
# 7563       2022-01-17 2021-04-23      Global         PDP  Development
#
#            Develop  Product QE (DPQE)
# Project ID
# 2854                       Kuo, Chris
# 5711                       Kuo, Chris
# 7011                       Kuo, Chris
# 7029                       Kuo, Chris
# 7563                       Fu, Ernest

# %%
value_vars = ['Working Prototype Built and Tested','Final Factory Prototypes Built','PR Date','MP Date']
pmsystem_project_dpqe_melted = df_consumer_dpqe.reset_index().melt(id_vars= ['Project ID','Project Name','Develop  Product QE (DPQE)'],value_vars=value_vars)
pmsystem_project_dpqe_melted.head()
# Out:
#    Project ID                     Project Name Develop  Product QE (DPQE)  \
# 0        2854               Product - GDC 7500                 Kuo, Chris
# 1        5711                 Product - GLA 85                 Kuo, Chris
# 2        7011  Xero G2i SatCom Scouting Camera                 Kuo, Chris
# 3        7029                 Alpha Dog Collar                 Kuo, Chris
# 4        7563                          Mercury                 Fu, Ernest
#
#                              variable      value
# 0  Working Prototype Built and Tested 2013-04-30
# 1  Working Prototype Built and Tested 2014-10-30
# 2  Working Prototype Built and Tested 2020-03-03
# 3  Working Prototype Built and Tested 2021-11-18
# 4  Working Prototype Built and Tested        NaT

# %%
pmsystem_project_dpqe_melted.rename(columns={'Develop  Product QE (DPQE)':'DPQE','variable':'Phase','value':'Date'},inplace=True)

# %%
pmsystem_project_dpqe_melted.Date = pmsystem_project_dpqe_melted.Date.dt.strftime('%Y-%m')

# %%
pmsystem_project_dpqe_melted = pmsystem_project_dpqe_melted[pmsystem_project_dpqe_melted.Date >= start_from]

# %%
pmsystem_project_dpqe_melted.isnull().sum()
# Out:
# Project ID      0
# Project Name    0
# DPQE            0
# Phase           0
# Date            0
# dtype: int64

# %% [markdown]
# Weight socre

# %%
pmsystem_project_dpqe_melted.loc[:,'weighted_score'] = pmsystem_project_dpqe_melted.loc[:,'Phase'].apply(lambda phase : 1 if (phase == 'Working Prototype Built and Tested') | (phase == 'MP Date') else 2 if phase=='Final Factory Prototypes Built' else 3 if phase=='PR Date' else 0)

# %%
pmsystem_project_dpqe_melted = pmsystem_project_dpqe_melted.rename(columns={"Project ID":'PM Project Id','Project Name':'PM Project Name'})

# %%
pmsystem_project_dpqe_melted.head()
# Out:
#     PM Project Id                PM Project Name  \
# 6            8510      Xero L60i Laser Navigator
# 9            9946                    GPSMAP 9000
# 12          10617  Force Kayak Propulsion System
# 15          10901                    eTrex Solar
# 19          11778               Tire Temp Sensor
#
#                               DPQE                               Phase  \
# 6                       Kuo, Chris  Working Prototype Built and Tested
# 9   Hsu, Jason(PQE);\nWang, Evelyn  Working Prototype Built and Tested
# 12                 Hsu, Jason(PQE)  Working Prototype Built and Tested
# 15                      Kuo, Chris  Working Prototype Built and Tested
# 19                       Ni, Wendy  Working Prototype Built and Tested
#
#        Date  weighted_score
# 6   2022-08               1
# 9   2022-06               1
# 12  2023-03               1
# 15  2022-12               1
# 19  2022-08               1

# %% [markdown]
# # PRweb

# %% [markdown]
# Read

# %%
prweb = pd.read_excel(prweb_file, header=1, usecols=[0,3])
prweb.head()
# Out:
#                             Project Name  PM Project Id
# 0  Xero B60i Laser Navigation Binoculars          13229
# 1                                 TGWW25          16227
# 2                                 LYWW24          15976
# 3          Force Kayak Propulsion System          10617
# 4                     LED Control Module          13134

# %% [markdown]
# Merge with data from PMsystem

# %%
prweb_pmsystem = pd.merge(left=pmsystem_project_dpqe_melted, right=prweb, how='left', left_on='PM Project Id', right_on='PM Project Id', suffixes=['_PMsystem','_prweb'])

# %%
prweb_pmsystem.head()
# Out:
#    PM Project Id            PM Project Name                            DPQE  \
# 0           8510  Xero L60i Laser Navigator                      Kuo, Chris
# 1           9946                GPSMAP 9000  Hsu, Jason(PQE);\nWang, Evelyn
# 2           9946                GPSMAP 9000  Hsu, Jason(PQE);\nWang, Evelyn
# 3           9946                GPSMAP 9000  Hsu, Jason(PQE);\nWang, Evelyn
# 4           9946                GPSMAP 9000  Hsu, Jason(PQE);\nWang, Evelyn
#
#                                 Phase     Date  weighted_score  \
# 0  Working Prototype Built and Tested  2022-08               1
# 1  Working Prototype Built and Tested  2022-06               1
# 2  Working Prototype Built and Tested  2022-06               1
# 3  Working Prototype Built and Tested  2022-06               1
# 4  Working Prototype Built and Tested  2022-06               1
#
#                 Project Name
# 0  Xero L60i Laser Navigator
# 1      GPSMAP 9000_Black Box
# 2          GPSMAP 9000 - 19"
# 3          GPSMAP 9000 - 24"
# 4           GPSMAP 9000 -27"

# %% [markdown]
# Handle GPSMAP 9000 19"

# %%
'Hsu, Jason(PQE);\nWang, Evelyn'.replace('\n','').split(';')
# Out:
# ['Hsu, Jason(PQE)', 'Wang, Evelyn']

# %%
# GPSMAP 9000 - 19" to Wang, Evelyn, others to Hsu, Jason(PQE)
def gpsmap_9000 (project_name, DPQE):
    if project_name == 'GPSMAP 9000 - 19"':
        return DPQE.replace('\n','').split(';')[1] #Wang, Evelyn
    elif project_name in ['GPSMAP 9000 - 22"','GPSMAP 9000 - 24"','GPSMAP 9000 -27"','GPSMAP 9000_Black Box']:
        return DPQE.replace('\n','').split(';')[0] #Hsu, Jason(PQE)
    else:
        return DPQE

# %%
prweb_pmsystem['DPQE'] = np.vectorize(gpsmap_9000)(prweb_pmsystem['Project Name'],prweb_pmsystem['DPQE'])

# %%
#Validate
prweb_pmsystem[prweb_pmsystem['PM Project Name'] == 'GPSMAP 9000']
# Out:
#      PM Project Id PM Project Name             DPQE  \
# 1             9946     GPSMAP 9000  Hsu, Jason(PQE)
# 2             9946     GPSMAP 9000     Wang, Evelyn
# 3             9946     GPSMAP 9000  Hsu, Jason(PQE)
# 4             9946     GPSMAP 9000  Hsu, Jason(PQE)
# 5             9946     GPSMAP 9000  Hsu, Jason(PQE)
# 46            9946     GPSMAP 9000  Hsu, Jason(PQE)
# 47            9946     GPSMAP 9000     Wang, Evelyn
# 48            9946     GPSMAP 9000  Hsu, Jason(PQE)
# 49            9946     GPSMAP 9000  Hsu, Jason(PQE)
# 50            9946     GPSMAP 9000  Hsu, Jason(PQE)
# 99            9946     GPSMAP 9000  Hsu, Jason(PQE)
# 100           9946     GPSMAP 9000     Wang, Evelyn
# 101           9946     GPSMAP 9000  Hsu, Jason(PQE)
# 102           9946     GPSMAP 9000  Hsu, Jason(PQE)
# 103           9946     GPSMAP 9000  Hsu, Jason(PQE)
# 163           9946     GPSMAP 9000  Hsu, Jason(PQE)
# 164           9946     GPSMAP 9000     Wang, Evelyn
# 165           9946     GPSMAP 9000  Hsu, Jason(PQE)
# 166           9946     GPSMAP 9000  Hsu, Jason(PQE)
# 167           9946     GPSMAP 9000  Hsu, Jason(PQE)
#
#                                   Phase     Date  weighted_score  \
# 1    Working Prototype Built and Tested  2022-06               1
# 2    Working Prototype Built and Tested  2022-06               1
# 3    Working Prototype Built and Tested  2022-06               1
# 4    Working Prototype Built and Tested  2022-06               1
# 5    Working Prototype Built and Tested  2022-06               1
# 46       Final Factory Prototypes Built  2022-12               2
# 47       Final Factory Prototypes Built  2022-12               2
# 48       Final Factory Prototypes Built  2022-12               2
# 49       Final Factory Prototypes Built  2022-12               2
# 50       Final Factory Prototypes Built  2022-12               2
# 99                              PR Date  2023-04               3
# 100                             PR Date  2023-04               3
# 101                             PR Date  2023-04               3
# 102                             PR Date  2023-04               3
# 103                             PR Date  2023-04               3
# 163                             MP Date  2023-06               1
# 164                             MP Date  2023-06               1
# 165                             MP Date  2023-06               1
# 166                             MP Date  2023-06               1
# 167                             MP Date  2023-06               1
#
#               Project Name
# 1    GPSMAP 9000_Black Box
# 2        GPSMAP 9000 - 19"
# 3        GPSMAP 9000 - 24"
# 4         GPSMAP 9000 -27"
# 5        GPSMAP 9000 - 22"
# 46   GPSMAP 9000_Black Box
# 47       GPSMAP 9000 - 19"
# 48       GPSMAP 9000 - 24"
# 49        GPSMAP 9000 -27"
# 50       GPSMAP 9000 - 22"
# 99   GPSMAP 9000_Black Box
# 100      GPSMAP 9000 - 19"
# 101      GPSMAP 9000 - 24"
# 102       GPSMAP 9000 -27"
# 103      GPSMAP 9000 - 22"
# 163  GPSMAP 9000_Black Box
# 164      GPSMAP 9000 - 19"
# 165      GPSMAP 9000 - 24"
# 166       GPSMAP 9000 -27"
# 167      GPSMAP 9000 - 22"

# %% [markdown]
# # Heatmap

# %%
overall = prweb_pmsystem.groupby(['DPQE','Project Name','Date']).agg({'weighted_score':'sum','Project Name':'count'}).sort_index(level='Date').rename(columns=({'weighted_score':'Weighted_Project_counts','Project Name':'Project_counts'})).unstack()

# %% [markdown]
# Overall w/o project names

# %%
plt.figure(figsize=(15,13))
sns.heatmap(prweb_pmsystem.groupby(['DPQE','Date']).count()['Project Name'].sort_index(level='Date').unstack(fill_value=0), cmap="YlGnBu", annot=True, linecolor='orange').set_title('Project_counts');
plt.savefig('(Output) Project_counts' ,bbox_inches = "tight", facecolor='white', transparent=False, dpi=300)

# %%
plt.figure(figsize=(15,13))
sns.heatmap(prweb_pmsystem.groupby(['DPQE','Date']).sum()['weighted_score'].sort_index(level='Date').unstack(fill_value=0), cmap="OrRd", annot=True).set_title('Weighted_Project_counts');
plt.savefig('(Output) Weighted_Project_counts' ,bbox_inches = "tight", facecolor='white', transparent=False, dpi=300)

# %% [markdown]
# Overall with project names

# %%
#plt.figure(figsize=(18,25))
#sns.heatmap(prweb_pmsystem.groupby(['DPQE','Project Name','Date']).sum()['weighted_score'].sort_index(level='Date').unstack(fill_value=0), cmap="OrRd", annot=True,linewidths=0.5, linecolor='orange').set_title('Weighted');

# %%
prweb_pmsystem.groupby(['DPQE','Project Name','Date']).sum()
# Out:
#                                                PM Project Id  weighted_score
# DPQE         Project Name             Date
# Fu, Ernest   Bounce(Waldo)            2022-10          10919               1
#              Cellular Tracking Module 2022-12          16095               1
#                                       2023-04          16095               2
#                                       2023-07          16095               3
#                                       2023-09          16095               1
# ...                                                      ...             ...
# Wang, Evelyn LED Control Module       2023-11          13134               3
#                                       2024-01          13134               1
#              Panoptix PS70 - (SSMB)   2022-10          10091               2
#                                       2023-01          10091               3
#                                       2023-03          10091               1
#
# [222 rows x 2 columns]

# %% [markdown]
# Details for each DPQE

# %%
for member in consumer_dpqe_list[:-1]: #-1 is to skip 'Hsu, Jason(PQE);\nWang, Evelyn' in tail of consumer_dpqe_list
    plt.figure(figsize=(13,8))
    sns.heatmap(prweb_pmsystem.groupby(['DPQE','Project Name','Date']).sum()['weighted_score'].sort_index(level='Date').unstack(fill_value=0).loc[member],cmap="OrRd", annot=True).set(title=member);
    #plt.savefig(getcwd()+'\(Output) {}'.format(member) ,bbox_inches = "tight", facecolor='white', transparent=False, dpi=300)

# %% [markdown]
# # 2022/09/02 request by Ray

# %% [markdown]
#  Find PM system projects MP dates from NOW

# %%
pmsystem_project2 = pd.read_excel(pmsystem_project_list_file, usecols=[0,1,5,8,9,10,12], 
    parse_dates=[2,3,4,5], engine='openpyxl')
pmsystem_project2 = pmsystem_project2[pmsystem_project2['Global/Asia']=='Global']
pmsystem_project2.head()
# Out:
# c:\Users\wangcooper\Miniconda3\envs\workspace\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    Project ID                  Project Name    MP Date    Category  \
# 0       15624   Catalyst Kart/Moto/Roadster 2023-03-20  Automotive
# 1       13009           Dash Cam Live (LTE) 2022-10-24  Automotive
# 3       16199  DC-2023 Premium Dash Cameras 2023-07-31  Automotive
# 5       16467                      Drive 53 2022-12-05  Automotive
# 6       11778              Tire Temp Sensor 2023-04-10  Automotive
#
#   Global/Asia PDP/Form107       Status
# 0      Global         PDP  Development
# 1      Global         PDP  Development
# 3      Global         PDP  Development
# 5      Global         PDP  Development
# 6      Global         PDP  Development

# %%
MPdate_from_now = pmsystem_project2[pmsystem_project2['MP Date'] > datetime.now()].sort_values(['Category','MP Date'], ascending=True).set_index('Category')
MPdate_from_now['MP Date'] = MPdate_from_now['MP Date'].dt.date
MPdate_from_now
# Out:
#             Project ID                           Project Name     MP Date  \
# Category
# Automotive       12983           Tread XL - Baja Race Edition  2022-10-17
# Automotive       13009                    Dash Cam Live (LTE)  2022-10-24
# Automotive       16467                               Drive 53  2022-12-05
# Automotive       15955                   Tread 8" OEM - Honda  2023-01-09
# Automotive       16069                               zumo XT2  2023-03-06
# ...                ...                                    ...         ...
# Outdoor          16205                           Descent Mk3s  2023-09-18
# Outdoor           8510              Xero L60i Laser Navigator  2023-09-18
# Outdoor          12994                            Descent Mk3  2023-10-02
# Outdoor          15469                            Descent X1i  2024-07-01
# Outdoor          13229  Xero B60i Laser Navigation Binoculars  2024-09-16
#
#            Global/Asia PDP/Form107       Status
# Category
# Automotive      Global         PDP  Development
# Automotive      Global         PDP  Development
# Automotive      Global         PDP  Development
# Automotive      Global         PDP  Development
# Automotive      Global         PDP  Development
# ...                ...         ...          ...
# Outdoor         Global         PDP  Development
# Outdoor         Global         PDP  Development
# Outdoor         Global         PDP  Development
# Outdoor         Global         PDP  Development
# Outdoor         Global         PDP  Development
#
# [61 rows x 6 columns]

# %%
MPdate_from_now_count = MPdate_from_now.groupby('Category')['Project Name'].count().to_frame().rename({'Project Name':'Count'},axis=1)
MPdate_from_now_count
# Out:
#             Count
# Category
# Automotive      8
# Fitness        11
# Marine         17
# Outdoor        25

# %%
No_MPdate = pmsystem_project2[pmsystem_project2['MP Date'].isnull()].sort_values(['Category','MP Date'], ascending=True).set_index('Category')
No_MPdate = No_MPdate[~No_MPdate.index.isin(['Aviation','Garmin Labs'])]
No_MPdate
# Out:
#             Project ID                                 Project Name MP Date  \
# Category
# Automotive       16319                           Aviation Headset -     NaT
# Automotive       16249                       dezl headset (2nd Gen)     NaT
# Fitness          16437                 Forerunner 165 and 165 Music     NaT
# Fitness          16197                                    Edge 1050     NaT
# Fitness          16345                            Elevate Accessory     NaT
# ...                ...                                          ...     ...
# Outdoor          16037  M60i Laser Navigation Binoculars 15/18x56mm     NaT
# Outdoor          16212                                 Marq (Gen 3)     NaT
# Outdoor          12279                                  Marq Hybrid     NaT
# Outdoor          15988                           Xero A2i Bow Sight     NaT
# Outdoor          15990                      Xero X20 Crossbow Scope     NaT
#
#            Global/Asia PDP/Form107       Status
# Category
# Automotive      Global         PDP     Concepts
# Automotive      Global         PDP     Concepts
# Fitness         Global         PDP  Development
# Fitness         Global         PDP     Concepts
# Fitness         Global         PDP     Concepts
# ...                ...         ...          ...
# Outdoor         Global         PDP     Concepts
# Outdoor         Global         PDP     Concepts
# Outdoor         Global         PDP     Concepts
# Outdoor         Global         PDP     Concepts
# Outdoor         Global         PDP     Concepts
#
# [73 rows x 6 columns]

# %%
No_MPdate_count = No_MPdate.groupby('Category')['Project Name'].count().to_frame().rename({'Project Name':'Count'},axis=1)
No_MPdate_count
# Out:
#             Count
# Category
# Automotive      2
# Fitness        14
# Marine         12
# OEM Auto       20
# Outdoor        25

# %% [markdown]
# Find Avation projects MP dates from PRweb

# %%
prweb2 = pd.read_excel(prweb_file, header=1, usecols=[0,1,5,6])
Aviation_PRweb = prweb2[prweb2['Category'] == 'Aviation'].sort_values('MP Date')
Aviation_PRweb
# Out:
#                          Project Name  Project Id  Category     MP Date
# 17       Product - G3X/G500TXi Hybrid        1050  Aviation  2023-07-01
# 18            Product - 1.3\" GTR/GNC         984  Aviation  2023-07-01
# 5                  Product - GDU147XW        1049  Aviation  2024-01-03
# 145  Product - Flight Stream Redesign         977  Aviation         NaN
# 146                 Product - GDU77XW        1048  Aviation         NaN

# %% [markdown]
# # to_excel

# %%
with pd.ExcelWriter(getcwd()+'\(Output) Data.xlsx', engine='openpyxl') as writer:

    overall.to_excel(writer, sheet_name='Overall')
    #auto_adjust_xlsx_column_width(overall, writer, sheet_name="overall", margin=5)
    
    ww_asia_diff_DPQE.to_excel(writer, sheet_name='ww_asia_diff_DPQE')
    auto_adjust_xlsx_column_width(ww_asia_diff_DPQE, writer, sheet_name="ww_asia_diff_DPQE", margin=5)
    
    projects_wo_DPQE.to_excel(writer, sheet_name='projects_wo_DPQE')
    auto_adjust_xlsx_column_width(projects_wo_DPQE, writer, sheet_name="projects_wo_DPQE", margin=5)
    
    multi_dpqe.to_excel(writer, sheet_name='multi_dpqe')
    auto_adjust_xlsx_column_width(multi_dpqe, writer, sheet_name="multi_dpqe", margin=5)

    MPdate_from_now_count.to_excel(writer, sheet_name='MPdate_from_now_count')
    auto_adjust_xlsx_column_width(MPdate_from_now_count, writer, sheet_name="MPdate_from_now_count", margin=3)
    
    MPdate_from_now.to_excel(writer, sheet_name='MPdate_from_now')
    auto_adjust_xlsx_column_width(MPdate_from_now, writer, sheet_name="MPdate_from_now", margin=3)
    
    No_MPdate_count.to_excel(writer, sheet_name='No_MPdate_count')
    auto_adjust_xlsx_column_width(No_MPdate_count, writer, sheet_name="No_MPdate_count", margin=3)
    
    No_MPdate.to_excel(writer, sheet_name='No_MPdate')
    auto_adjust_xlsx_column_width(No_MPdate, writer, sheet_name="No_MPdate", margin=3)

    Aviation_PRweb.to_excel(writer, sheet_name='Aviation_PRweb')
    auto_adjust_xlsx_column_width(Aviation_PRweb, writer, sheet_name="Aviation_PRweb", margin=3)
