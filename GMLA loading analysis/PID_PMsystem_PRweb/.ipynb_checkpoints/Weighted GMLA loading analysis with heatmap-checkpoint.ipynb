# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('GMLA.xlsx', sheet_name='GMLAL Status Summary- 2022 New')

# %%
# Remove projects without GMLA
df = df[df['GMLA Result Complete\n(PQE Maintain)'].isin(['N','Y'])]

# %%
df = df.iloc[:,:10]

# %%
df.rename(columns={df.columns[6]: "Close meeting Target date", 
                   df.columns[7]: "Close meeting Actual date",
                   df.columns[8]: "GMLA start date",
                   df.columns[1]: "Project Name"}, inplace=True)

# %%
df.drop((df.columns[3:5]), axis=1, inplace=True)

# %%
#Replace MAR

df['DPQE'].replace('Cooper Wang/ Wendy Ni','Cooper Wang', inplace=True)

# %%
replace_nan_list = ['No MPM','TBD','No WP request','project cancelled','no need','Net yet']
df.replace(replace_nan_list,np.NaN, inplace=True)

# %%
df['Close meeting Actual date'] = pd.to_datetime(df['Close meeting Actual date'])

# %%
df['combined_date'] = df['Close meeting Actual date'].fillna(df['Close meeting Target date'])

# %%
df
# Out:
#        Category                                       Project Name  \
# 0        Marine  Fusion - Apollo Amplifiers 6 / 8 channel (Tune...
# 1      Aviation                                           Aera 760
# 4       Outdoor                                        GPSMAP 66sr
# 5       Outdoor                                         Alpha 200i
# 7       Outdoor                               fenix 6 Solar (2020)
# ..          ...                                                ...
# 504     Fitness                                        Tacx NEO 3M
# 505     Fitness                                        Tacx NEO 3M
# 506  Automotive                                Tread 8" OEM w/ CAN
# 507  Automotive                           dezl OTR Series 2022- 7"
# 524      Marine                     GMR xHD3 Magnetron Open Arrays
#
#            Phase Name GMLA Phase Close meeting Target date  \
# 0     Detailed Design      GMLA1                2020-10-19
# 1     Detailed Design      GMLA1                       NaT
# 4    Factory Prototye      GMLA2                2019-12-27
# 5    Factory Prototye      GMLA2                2019-12-20
# 7    Factory Prototye      GMLA2                2019-12-20
# ..                ...        ...                       ...
# 504  Factory Prototye      GMLA2                2023-02-08
# 505         Pilot Run      GMLA3                2023-04-12
# 506   Detailed Design      GMLA1                       NaT
# 507         Pilot Run      GMLA3                2022-03-08
# 524   Detailed Design      GMLA1                       NaT
#
#     Close meeting Actual date      GMLA start date        DPQE combined_date
# 0                  2019-07-31  2019-07-31 00:00:00   Jason Hsu    2019-07-31
# 1                  2019-08-13  2019-08-13 00:00:00  Abner Tsai    2019-08-13
# 4                  2019-12-13  2019-12-13 00:00:00   Chris Kuo    2019-12-13
# 5                         NaT  2019-12-20 00:00:00   Chris Kuo    2019-12-20
# 7                  2019-12-26  2019-12-26 00:00:00  Abner Tsai    2019-12-26
# ..                        ...                  ...         ...           ...
# 504                       NaT  2023-02-08 00:00:00   Chris Kuo    2023-02-08
# 505                       NaT  2023-04-12 00:00:00   Chris Kuo    2023-04-12
# 506                       NaT             00:00:00    Wendy Ni           NaT
# 507                       NaT  2022-04-07 00:00:00    Wendy Ni    2022-03-08
# 524                2022-04-18  2022-04-18 00:00:00   Jason Hsu    2022-04-18
#
# [437 rows x 9 columns]

# %%
df = df[df['combined_date'].notnull()]

# %%
df = df[df['combined_date']>'2022-01-01']

# %%
df['yearmonth']=df['combined_date'].dt.strftime('%Y-%m')

# %%
df['weighted'] = df['GMLA Phase'].apply(lambda gmla : 1 if gmla=='GMLA1' else 2 if gmla=='GMLA2' else 3 if gmla=='GMLA3' else 0)

# %%
df
# Out:
#        Category                    Project Name        Phase Name GMLA Phase  \
# 277      Marine         ECHOMAP UHD2 (Touch) 6"  Factory Prototye      GMLA2
# 281      Marine         ECHOMAP UHD2 (Touch) 6"         Pilot Run      GMLA3
# 289     Outdoor      Xero C1/C1 PRO Chronograph   Detailed Design      GMLA1
# 293  Automotive        dezl OTR Series 2022- 6"  Factory Prototye      GMLA2
# 297      Marine                          GHC 50         Pilot Run      GMLA3
# ..          ...                             ...               ...        ...
# 502     Fitness                  Forerunner 965         Pilot Run      GMLA3
# 504     Fitness                     Tacx NEO 3M  Factory Prototye      GMLA2
# 505     Fitness                     Tacx NEO 3M         Pilot Run      GMLA3
# 507  Automotive        dezl OTR Series 2022- 7"         Pilot Run      GMLA3
# 524      Marine  GMR xHD3 Magnetron Open Arrays   Detailed Design      GMLA1
#
#     Close meeting Target date Close meeting Actual date      GMLA start date  \
# 277                2022-05-31                       NaT  2022-05-31 00:00:00
# 281                2022-08-08                       NaT  2022-08-08 00:00:00
# 289                2021-07-08                2022-01-05  2022-01-05 00:00:00
# 293                2022-01-14                2022-01-14  2022-01-14 00:00:00
# 297                2022-01-05                       NaT  2022-01-05 00:00:00
# ..                        ...                       ...                  ...
# 502                2023-02-09                       NaT  2023-02-09 00:00:00
# 504                2023-02-08                       NaT  2023-02-08 00:00:00
# 505                2023-04-12                       NaT  2023-04-12 00:00:00
# 507                2022-03-08                       NaT  2022-04-07 00:00:00
# 524                       NaT                2022-04-18  2022-04-18 00:00:00
#
#           DPQE combined_date yearmonth  weighted
# 277  Jason Hsu    2022-05-31   2022-05         2
# 281  Jason Hsu    2022-08-08   2022-08         3
# 289  Chris Kuo    2022-01-05   2022-01         1
# 293   Wendy Ni    2022-01-14   2022-01         2
# 297  Jason Hsu    2022-01-05   2022-01         3
# ..         ...           ...       ...       ...
# 502  Ernest Fu    2023-02-09   2023-02         3
# 504  Chris Kuo    2023-02-08   2023-02         2
# 505  Chris Kuo    2023-04-12   2023-04         3
# 507   Wendy Ni    2022-03-08   2022-03         3
# 524  Jason Hsu    2022-04-18   2022-04         1
#
# [135 rows x 11 columns]

# %%
t1_dpqe = ['Cooper Wang', 'Ernest Fu','Aalto Lo', 'Ernest Fu/ Aalto Lo']
aoem_dpqe = ['Simon Ko','Ray Hu','Cherry Tsai','Allen Chen/ Ray Hu']

# %%
df_aoem = df[df['DPQE'].isin(aoem_dpqe)]
df_consumer = df[(~df['DPQE'].isin(aoem_dpqe)) & (df['DPQE']!='Not assigned yet')]

# %%
df_consumer = df_consumer.groupby(['DPQE','yearmonth']).sum()

# %%
df_consumer.unstack(fill_value=0)['weighted']
# Out:
# yearmonth            2022-01  2022-02  2022-03  2022-04  2022-05  2022-06  \
# DPQE
# Aalto Lo                   0        0        2        3        2        0
# Chris Kuo                  3       11        7       11        6        6
# Cooper Wang                2        1        0        0        1        4
# Ernest Fu                  1        4        6        3        2        0
# Ernest Fu/ Aalto Lo        0        0        0        0        0        0
# Jason Hsu                  6        9        3        3       13        7
# Wendy Ni                  13        2       15        3        0        0
#
# yearmonth            2022-07  2022-08  2022-09  2022-10  2022-11  2022-12  \
# DPQE
# Aalto Lo                   5        0        0        0        0        0
# Chris Kuo                 19       10        2        0        6        2
# Cooper Wang                2        2        4        9       14        0
# Ernest Fu                  0        3        0        2        2        2
# Ernest Fu/ Aalto Lo        0        0        0        0        0        2
# Jason Hsu                  8       11        0        2        0        0
# Wendy Ni                   0        0        0        0        0        0
#
# yearmonth            2023-01  2023-02  2023-03  2023-04
# DPQE
# Aalto Lo                   0        0        0        0
# Chris Kuo                  3        2        0        3
# Cooper Wang                7        0        6        0
# Ernest Fu                  3        6        3        0
# Ernest Fu/ Aalto Lo        0        0        3        0
# Jason Hsu                  3        0        0        0
# Wendy Ni                   0        0        0        0

# %%
plt.figure(figsize=(13,10))
sns.heatmap(df_consumer.unstack(fill_value=0)['weighted'],cmap="YlGnBu", annot=True).set(title='Consumer')
plt.savefig('Counsumer Overview',bbox_inches = "tight")

# %%
df_aoem = df_aoem.groupby(['DPQE','yearmonth']).sum()

# %%
plt.figure(figsize=(13,10))
sns.heatmap(df_aoem.unstack(fill_value=0)['weighted'],cmap="YlGnBu", annot=True).set(title='AOEM')
plt.savefig('AOEM Overview',bbox_inches = "tight")

# %%
df2 = df.groupby(['DPQE','yearmonth','Project Name']).sum()

# %%
plt.figure(figsize=(13,10))
sns.heatmap(df2.loc['Chris Kuo']['weighted'].unstack(fill_value=0,level=0),cmap="OrRd", annot=True).set(title='Chris Kuo');

# %%
plt.figure(figsize=(13,10))
sns.heatmap(df2.loc['Jason Hsu']['weighted'].unstack(fill_value=0,level=0), annot=True,cmap="OrRd").set(title='Jason Hsu');
plt.savefig('Jason Hsu',bbox_inches = "tight")

# %%
plt.figure(figsize=(13,10))
sns.heatmap(df2.loc['Wendy Ni']['weighted'].unstack(fill_value=0,level=0), annot=True,cmap="OrRd").set(title='Wendy Ni');

# %%
plt.figure(figsize=(13,10))
sns.heatmap(df2.loc['Ernest Fu']['weighted'].unstack(fill_value=0,level=0,),cmap="OrRd", annot=True).set(title='Ernest Fu');

# %%
plt.figure(figsize=(13,10))
sns.heatmap(df2.loc['Cooper Wang']['weighted'].unstack(fill_value=0,level=0), annot=True,cmap="OrRd").set(title='Cooper Wang');

# %%
plt.figure(figsize=(13,10))
sns.heatmap(df2.loc['Aalto Lo']['weighted'].unstack(fill_value=0,level=0,),cmap="OrRd", annot=True).set(title='Aalto Lo');
