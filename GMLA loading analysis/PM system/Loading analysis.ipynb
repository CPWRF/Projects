# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
project_list_file = 'ProjectListExport_2022-05-20-09-13-56-082.xls'
cft_list_file = 'CFTListExport_2022-05-20-09-10-10-246.xls'

# %%
project = pd.read_excel(project_list_file, usecols=[0,1,3,4,5,6,9,10], parse_dates=[2,3,4,5])
cft = pd.read_excel(cft_list_file, usecols=[0,44])
# Out:
# c:\Users\wangcooper\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
cft
# Out:
#       Project ID Develop  Product QE (DPQE)
# 0          13939                 Kuo, Chris
# 1          15274                 Kuo, Chris
# 2          15624                  Lo, Aalto
# 3          13009                 Kuo, Chris
# 4          14984                 Kuo, Chris
# ...          ...                        ...
# 3087        7141               Wang, Cooper
# 3088        2358                        NaN
# 3089        2542                        NaN
# 3090        2263                        NaN
# 3091        2333                        NaN
#
# [3092 rows x 2 columns]

# %%
project = project[(project['Global/Asia'] == 'Global') & (project['PDP/Form107'] == 'PDP')]
project
# Out:
#      Project ID                                       Project Name  \
# 0         13939                           BC50 & BC50 Night Vision
# 2         15624                        Catalyst Kart/Moto/Roadster
# 3         13009                                Dash Cam Live (LTE)
# 5         13139                                       Dezl Headset
# 6         15861                               dezl OTR Series 2022
# ..          ...                                                ...
# 372       12040                                            Tempe 2
# 373       15988                                 Xero A2i Bow Sight
# 374       16048  Xero G1c Photo Transmitting Cellular Scouting ...
# 375       13239                     Xero P60i Laser Spotting Scope
# 376       15990                            Xero X1s Crossbow Scope
#
#     Working Prototype Built and Tested Final Factory Prototypes Built  \
# 0                           2021-08-20                            NaT
# ...

# %%
project_cft = pd.merge(left=project, right=cft)
project_cft
# Out:
#      Project ID                                       Project Name  \
# 0         13939                           BC50 & BC50 Night Vision
# 1         15624                        Catalyst Kart/Moto/Roadster
# 2         13009                                Dash Cam Live (LTE)
# 3         13139                                       Dezl Headset
# 4         15861                               dezl OTR Series 2022
# ..          ...                                                ...
# 301       12040                                            Tempe 2
# 302       15988                                 Xero A2i Bow Sight
# 303       16048  Xero G1c Photo Transmitting Cellular Scouting ...
# 304       13239                     Xero P60i Laser Spotting Scope
# 305       15990                            Xero X1s Crossbow Scope
#
#     Working Prototype Built and Tested Final Factory Prototypes Built  \
# 0                           2021-08-20                            NaT
# ...

# %%
project_cft.columns
# Out:
# Index(['Project ID', 'Project Name', 'Working Prototype Built and Tested',
#        'Final Factory Prototypes Built', 'MP Date', 'PR Date', 'Global/Asia',
#        'PDP/Form107', 'Develop  Product QE (DPQE)'],
#       dtype='object')

# %%
project_cft['Develop  Product QE (DPQE)'].unique()
# Out:
# array(['Kuo, Chris', 'Lo, Aalto', 'Ni, Wendy', 'Hsu, Jason(PQE)', nan,
#        'Dong, Reta', 'Fu, Ernest', 'Fu, Ernest;\nLo, Aalto',
#        'Chen, Tiffany(QA);\nPuder, Kristi;\nKelly, Joan;\nSantos, Mila;\nHolland, Wendy;\nBennett, Travis;\nTugui, Susanne;\nSauer, Stefanie;\nBruns, Melanie;\nChen, Allen;\nTsai, Cherry',
#        'Chen, Tiffany(QA);\nKelly, Joan;\nBruns, Melanie;\nKocon, Andy;\nYamnitz, Ryan;\nJundi, Ramzi;\nOverzier, Martin;\nKeller, Marina;\nHu, Ray;\nHu, Ray;\nTsai, Cherry;\nHsu, Jessie',
#        'Tsai, Cherry;\nPeranovic, Predrag;\nNefzger, Bernadette;\nKelly, Joan;\nPinte, Marius;\nJones, Rachel;\nYamnitz, Ryan;\nBruns, Melanie',
#        'Not Applicable', 'Chen, Tiffany(QA);\nYu, Arthur', 'Yu, Arthur',
#        'Hsu, Jin', 'Tsai, Abner', 'Wang, Cooper',
#        'Wang, Cooper;\nNi, Wendy'], dtype=object)

# %%
consumer_dpqe_list = ['Lo, Aalto','Kuo, Chris','Wang, Cooper', 'Fu, Ernest','Fu, Ernest;\nLo, Aalto','Hsu, Jason(PQE)','Ni, Wendy']

# %%
df_consumer_dpqe = project_cft[project_cft['Develop  Product QE (DPQE)'].isin(consumer_dpqe_list)]
df_consumer_dpqe
# Out:
#      Project ID                    Project Name  \
# 0         13939        BC50 & BC50 Night Vision
# 1         15624     Catalyst Kart/Moto/Roadster
# 2         13009             Dash Cam Live (LTE)
# 3         13139                    Dezl Headset
# 4         15861            dezl OTR Series 2022
# ..          ...                             ...
# 296       14604          L20 Laser Range Finder
# 297       12716             LIDAR-Lite V4 Laser
# 300       12279                     Marq Hybrid
# 301       12040                         Tempe 2
# 304       13239  Xero P60i Laser Spotting Scope
#
#     Working Prototype Built and Tested Final Factory Prototypes Built  \
# 0                           2021-08-20                            NaT
# 1                           2022-06-24                     2022-10-10
# 2                           2021-06-25                     2022-03-11
# 3                           2021-06-18                     2021-10-15
# ...

# %%
df_consumer_dpqe.groupby(['Develop  Product QE (DPQE)','Project Name']).count()
# Out:
#                                                          Project ID  \
# Develop  Product QE (DPQE) Project Name
# Fu, Ernest                 2022 vivofit jr. 3 SKUs                1
#                            Bounce                                 1
#                            Forerunner 255 Small                   1
#                            Forerunner 255 and 255 Music           1
#                            Forerunner 265                         1
# ...                                                             ...
# Wang, Cooper               Enduro 2023                            1
#                            Marq Hybrid                            1
#                            fenix 7 Pro                            1
#                            fenix 7S Pro                           1
#                            fenix 7X Pro                           1
#
#                                                          Working Prototype Built and Tested  \
# ...
