# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename = 'report.xlsx'

# %%
pid = pd.read_excel(filename, sheet_name='PID Summary')

# %%
FYR = pid[pid['FYR  %'] < 97]
FYR
# Out:
#                   Process Type  ItemNameType  FPY  %  FYR  %  Retest Rate %  \
# 15          DescentG1_ProdScan         14422   83.81   95.95           33.9
# 16       inReach_mini2_Compass         13156    0.00    0.00            0.0
# 21  DescentG1_Solar_Felica_SPC         14657    0.00   50.00          250.0
#
#     Retest Rate(WO. ProductFail)  % Tested ESN QTY / Output  Avg Pass (sec)  \
# 15                            30.47                 593/569      104.229687
# 16                             0.00                      1/             NaN
# 21                           250.00                     2/2       30.000000
#
#                TestDate (UTC)
# 15  2021-09-20T02:35:54+00:00
# 16  2021-09-15T02:28:16+00:00
# 21  2021-09-16T04:14:06+00:00

# %%
# Split QTY and convert them into Int
pid['Tested ESN QTY'] = pid['Tested ESN QTY / Output'].apply(lambda qty : int(qty.split('/')[0]))

# %%
pid_retry_rate = pid[pid['Retest Rate %'] > 10].sort_values('Retest Rate %', ascending=False)

# %%
pid_retry_rate
# Out:
#                   Process Type  ItemNameType  FPY  %  FYR  %  Retest Rate %  \
# 21  DescentG1_Solar_Felica_SPC         14657    0.00   50.00         250.00
# 19    DescentG1_EasyCardBundle         15244   76.54  100.00          40.74
# 23       RabbitCard_QC_TestEnv         14748   80.00  100.00          40.00
# 15          DescentG1_ProdScan         14422   83.81   95.95          33.90
# 17          DescentG1_Solar_FT         14379   90.75   99.70          25.67
# 5                DescentG1_FT1         13467   91.21   99.04          22.68
# 13              DescentG1_Gyro         13626   89.44   99.84          21.12
# 4               Airtight_table          8837   93.61   99.36          16.93
# 6                DescentG1_FT2         13469   93.93   99.68          16.93
# 2                 DescentG1_CT         14035   91.89   99.68          15.90
# 12              DescentG1_Baro         14163   93.91   99.52          14.74
# ...

# %%
# Load Test Result worksheet
test_result = pd.read_excel('report.xlsx', sheet_name='Test Result').sort_values('Retest%', ascending=False)

# %%
test_result
# Out:
#      ItemName Type                Process Type  Item  \
# 15           14657  DescentG1_Solar_Felica_SPC    23
# 26           13156       inReach_mini2_Compass     6
# 4            14748       RabbitCard_QC_TestEnv     5
# 16           15244    DescentG1_EasyCardBundle     9
# 25           14379          DescentG1_Solar_FT    24
# ..             ...                         ...   ...
# 119          13626              DescentG1_Gyro     6
# 121          13626              DescentG1_Gyro     9
# 122          13626              DescentG1_Gyro    21
# 123          13626              DescentG1_Gyro    36
# 156          13686             DescentG1_RTESN    25
#
#                                ItemName Count/Count ESN  Retest%  \
# 15            Check Console Data Prefix             5/2   250.00
# 26                        Product Check             1/1   100.00
# 4            Compare Card ID to QC Tool           10/25    40.00
# ...

# %%
test_result_drop = test_result.drop_duplicates('Process Type')

# %%
final_result = pid_retry_rate.merge(how='left', on="Process Type", right=test_result_drop).sort_values('Retest Rate %', ascending=False)
final_result = final_result[['Process Type','Retest Rate %','Tested ESN QTY','Item','ItemName','Retest%','Comment']].head(5)
final_result
# Out:
#                  Process Type  Retest Rate %  Tested ESN QTY  Item  \
# 0  DescentG1_Solar_Felica_SPC         250.00               2    23
# 1    DescentG1_EasyCardBundle          40.74              81     9
# 2       RabbitCard_QC_TestEnv          40.00              25     5
# 3          DescentG1_ProdScan          33.90             593     6
# 4          DescentG1_Solar_FT          25.67             335    24
#
#                            ItemName  Retest%  \
# 0         Check Console Data Prefix   250.00
# 1          Balance check via reader    24.69
# 2        Compare Card ID to QC Tool    40.00
# 3   [Solar1sun] 7446 Test_post[Voc]     7.93
# 4  [0.5sun] [IOP] Min VSOL Voltage     12.24
#
#                                              Comment
# 0  It's a Felica issue, there is a little error w...
# 1  在機台12點鐘方向才可讀取餘額\nSimilar to the causes of othe...
# 2  讀卡機顯示無法讀取機台，重測即PASS\nI think it may be softwar...
# 3  確認此測項需求性(移除or改下限or使用治具)\nThis station is for c...
# ...

# %%
raw = pd.read_excel(filename, sheet_name='Raw data')

# %%
#Find test result distribution Matplotlib version

#for i in final_result.index:
#    plt.figure(figsize=(10,8))
#    raw.loc[(raw.ProcessType == final_result.iloc[i,0]),'Item'+str(final_result.iloc[i,3])].plot.hist().set_title("Top"+str(i+1)+", "+final_result.iloc[i,0]+", "+"Item"+str(final_result.iloc[i,3]))

# %%
#Find test result distribution seaborn version

for i in range(len(final_result.index)):
    plt.figure(figsize=(20,8))
    
    data = raw.loc[raw.ProcessType == final_result.iloc[i,0]]
    x = 'Item'+str(final_result.iloc[i,3])
    title = "Top"+str(i+1)+", "+final_result.iloc[i,0]+", "+"Item"+str(final_result.iloc[i,3])
    
    sns.histplot(data=data, x=x, hue='Result').set_title(title)

# %%
raw['Item24_clipped'] = raw['Item24'].clip(lower=700,upper=1000)

# %%
plt.figure(figsize=(15,8))
plt.grid(True)
sns.histplot(data=raw.loc[(raw.ProcessType == 'DescentG1_Solar_FT')],x='Item24_clipped', hue="Result")
# Out:
# <AxesSubplot:xlabel='Item24_clipped', ylabel='Count'>
