# %%
import pyodbc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.tseries.offsets import BDay
from datetime import datetime
import pytz

# %%
import os
def GetDesktopPath():
    return os.path.join(os.path.expanduser("~"), 'Desktop')

path = GetDesktopPath()

# %%
scope = '2021-01'

# %%
my_query = """ 
SELECT [projectSizeId]
      ,[PROJECT_SIZE_NAME] as 'Project_Name'
      ,[typeName] as 'Phase'
      ,[status]
      ,[rejectReason]
      ,[kickOffMeetingDate]
      ,[baseOverDueDate] as 'closeMeetingDate'
      ,[submitDate] as 'GMLASubmitDate'
      ,[IsByPass] 
  FROM [PR_WEB2].[dbo].[T_GMLA_CKLIST_CONFIRM]

  LEFT JOIN [PR_WEB2].[dbo].[T_PS_ProdSizeRelateInfo]
  on projectSizeId = PROJECT_SIZE_ID
  /* Join project names */

  LEFT JOIN [PR_WEB2].[dbo].[T_GMLA_BS_VERSION_TYPE]
  ON typeId = [PR_WEB2].[dbo].[T_GMLA_BS_VERSION_TYPE].id
  /* Join GMLA#1/#2/#3 name*/

  WHERE [IsByPass] = '0'
"""

# %%
server = 'T1-PE-SUPPORT' 
database = 'PR_WEB2' 
username = 'pieng' 
password = 'Q2iT5cwHJW3FH' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
query = my_query
df = pd.read_sql(query, cnxn)

# %%
df
# Out:
#      projectSizeId                                       Project_Name  \
# 0              766                                             GAD 13
# 1              766                                             GAD 13
# 2              766                                             GAD 13
# 3              775                                             zumo X
# 4              775                                             zumo X
# ..             ...                                                ...
# 546           1126  Next gen GMR magnetron domes -GMR 24 XHD NEXT GEN
# 547           1126  Next gen GMR magnetron domes -GMR 24 XHD NEXT GEN
# 548           1127      Connect 50 transition to Taiwan Manufacturing
# 549           1127      Connect 50 transition to Taiwan Manufacturing
# 550           1127      Connect 50 transition to Taiwan Manufacturing
#
#        Phase  status rejectReason kickOffMeetingDate closeMeetingDate  \
# 0    GMLA #1       0         None               None             None
# 1    GMLA #2       0         None               None             None
# 2    GMLA #3       0         None               None             None
# 3    GMLA #1       0         None               None             None
# 4    GMLA #2       0         None               None             None
# ..       ...     ...          ...                ...              ...
# 546  GMLA #2       0         None               None             None
# 547  GMLA #3       0         None               None             None
# 548  GMLA #1       0         None               None             None
# 549  GMLA #2       0         None               None             None
# 550  GMLA #3       0         None               None             None
#
#     GMLASubmitDate  IsByPass
# 0             None         0
# 1             None         0
# 2             None         0
# 3             None         0
# 4             None         0
# ..             ...       ...
# 546           None         0
# 547           None         0
# 548           None         0
# 549           None         0
# 550           None         0
#
# [551 rows x 9 columns]

# %%
df.replace('0001-01-08 00:00:00.0000000 +08:00', np.nan, inplace=True)

# %%
df.closeMeetingDate = pd.to_datetime(df.closeMeetingDate, utc=True)
df.GMLASubmitDate = pd.to_datetime(df.GMLASubmitDate,utc=True)

# %%
df.closeMeetingDate = df.closeMeetingDate.dt.tz_convert('Asia/Taipei')
df.GMLASubmitDate = df.GMLASubmitDate.dt.tz_convert('Asia/Taipei')

# %%
df['target_GMLASubmitDate'] = (df.closeMeetingDate + BDay(9))

# %% [markdown]
# Forecast

# %%
forecast = df[(df.status == 0) & (df.target_GMLASubmitDate> datetime.now(pytz.timezone('Asia/Taipei')))].sort_values('closeMeetingDate')
forecast
# Out:
#      projectSizeId                            Project_Name    Phase  status  \
# 297           1029  Instinct Hybrid Analog/Digital(Ripley)  GMLA #2       0
# 372           1059                 ECHOMAP UHD2 (Touch) 7"  GMLA #2       0
# 324           1041                 ECHOMAP UHD2 (Touch) 9"  GMLA #2       0
# 273           1018                 ECHOMAP UHD2 (Touch) 6"  GMLA #2       0
# 416           1076                     fenix 7S Pro (2022)  GMLA #1       0
# 50             815                           BMW MGU22/IDC  GMLA #3       0
# 250           1006                         Descent S1 Buoy  GMLA #2       0
# 461           1092                   EPIX PRO (Gen 2) 42mm  GMLA #1       0
# 98             856                        Alpha Dog Collar  GMLA #2       0
# 267           1016               Xero L60i Laser Navigator  GMLA #1       0
# 185            964      TXTW22_Drive+3.0 (Taroko) -12.3 DA  GMLA #2       0
# 200            972                            Marq (Gen 2)  GMLA #2       0
# 163            949                            Approach Z50  GMLA #2       0
# 367           1058              Descent Mk3 Series - Small  GMLA #1       0
# 355           1054                        GPSMAP 9000 -27"  GMLA #3       0
# 346           1051                       GPSMAP 9000 - 19"  GMLA #3       0
# 209            978            Force Kraken Trolling Motor   GMLA #2       0
# 432           1081                 RV Fixed Displays - 10"  GMLA #2       0
# 430           1080                  RV Fixed Displays - 7"  GMLA #2       0
# 349           1052                       GPSMAP 9000 - 22"  GMLA #3       0
# 352           1053                       GPSMAP 9000 - 24"  GMLA #3       0
# 351           1052                       GPSMAP 9000 - 22"  GMLA #2       0
# 354           1053                       GPSMAP 9000 - 24"  GMLA #2       0
# 348           1051                       GPSMAP 9000 - 19"  GMLA #2       0
# 357           1054                        GPSMAP 9000 -27"  GMLA #2       0
# 179            961                         BlueNET Gateway  GMLA #2       0
# 182            962                          BlueNET Switch  GMLA #2       0
#
#     rejectReason                  kickOffMeetingDate  \
# 297         None  2022-02-28 16:00:00.0000000 +00:00
# 372         None                                None
# 324         None                                None
# 273         None                                None
# 416         None                                None
# 50          None                                None
# 250         None  2022-06-29 16:00:00.0000000 +00:00
# 461         None                                None
# 98          None                                None
# 267         None                                None
# 185         None                                None
# 200         None  2022-06-07 16:00:00.0000000 +00:00
# 163         None                                None
# 367         None                                None
# 355         None                                None
# 346         None                                None
# 209         None  2021-06-14 16:00:00.0000000 +00:00
# 432         None                                None
# 430         None                                None
# 349         None                                None
# 352         None                                None
# 351         None                                None
# 354         None                                None
# 348         None                                None
# 357         None                                None
# 179         None  2022-02-22 16:00:00.0000000 +00:00
# 182         None                                None
#
#              closeMeetingDate GMLASubmitDate  IsByPass  \
# 297 2022-06-14 00:00:00+08:00            NaT         0
# 372 2022-06-15 00:00:00+08:00            NaT         0
# 324 2022-06-15 00:00:00+08:00            NaT         0
# 273 2022-06-15 00:00:00+08:00            NaT         0
# 416 2022-06-24 00:00:00+08:00            NaT         0
# 50  2022-06-30 00:00:00+08:00            NaT         0
# 250 2022-06-30 00:00:00+08:00            NaT         0
# 461 2022-06-30 00:00:00+08:00            NaT         0
# 98  2022-06-30 00:00:00+08:00            NaT         0
# 267 2022-07-04 00:00:00+08:00            NaT         0
# 185 2022-07-11 00:00:00+08:00            NaT         0
# 200 2022-07-28 00:00:00+08:00            NaT         0
# 163 2022-07-29 00:00:00+08:00            NaT         0
# 367 2022-07-31 00:00:00+08:00            NaT         0
# 355 2022-08-17 00:00:00+08:00            NaT         0
# 346 2022-08-17 00:00:00+08:00            NaT         0
# 209 2022-09-01 00:00:00+08:00            NaT         0
# 432 2022-09-12 00:00:00+08:00            NaT         0
# 430 2022-09-12 00:00:00+08:00            NaT         0
# 349 2022-09-15 00:00:00+08:00            NaT         0
# 352 2022-09-15 00:00:00+08:00            NaT         0
# 351 2022-11-18 00:00:00+08:00            NaT         0
# 354 2022-11-18 00:00:00+08:00            NaT         0
# 348 2022-11-18 00:00:00+08:00            NaT         0
# 357 2022-11-18 00:00:00+08:00            NaT         0
# 179 2022-12-01 00:00:00+08:00            NaT         0
# 182 2022-12-01 00:00:00+08:00            NaT         0
#
#         target_GMLASubmitDate
# 297 2022-06-27 00:00:00+08:00
# 372 2022-06-28 00:00:00+08:00
# 324 2022-06-28 00:00:00+08:00
# 273 2022-06-28 00:00:00+08:00
# 416 2022-07-07 00:00:00+08:00
# 50  2022-07-13 00:00:00+08:00
# 250 2022-07-13 00:00:00+08:00
# 461 2022-07-13 00:00:00+08:00
# 98  2022-07-13 00:00:00+08:00
# 267 2022-07-15 00:00:00+08:00
# 185 2022-07-22 00:00:00+08:00
# 200 2022-08-10 00:00:00+08:00
# 163 2022-08-11 00:00:00+08:00
# 367 2022-08-11 00:00:00+08:00
# 355 2022-08-30 00:00:00+08:00
# 346 2022-08-30 00:00:00+08:00
# 209 2022-09-14 00:00:00+08:00
# 432 2022-09-23 00:00:00+08:00
# 430 2022-09-23 00:00:00+08:00
# 349 2022-09-28 00:00:00+08:00
# 352 2022-09-28 00:00:00+08:00
# 351 2022-12-01 00:00:00+08:00
# 354 2022-12-01 00:00:00+08:00
# 348 2022-12-01 00:00:00+08:00
# 357 2022-12-01 00:00:00+08:00
# 179 2022-12-14 00:00:00+08:00
# 182 2022-12-14 00:00:00+08:00

# %%
df.dropna(axis=0, subset=['GMLASubmitDate'], inplace=True)

# %%
df['on_time'] = df.target_GMLASubmitDate.dt.strftime('%Y-%m-%d') >= df.GMLASubmitDate.dt.strftime('%Y-%m-%d')

# %%
on_time = df.drop_duplicates(subset=['Project_Name','Phase']).sort_values(['Project_Name','Phase'])

# %% [markdown]
# Handle delay_but_rejected projects

# %%
def delay_but_rejected(on_time, rejectReason):
    if on_time == False and rejectReason != None:
        return True
    else:
        return False

# %%
on_time['delay_but_rejected'] = np.vectorize(delay_but_rejected)(on_time['on_time'], on_time['rejectReason'])

# %%
on_time = on_time[on_time.target_GMLASubmitDate> scope]

# %% [markdown]
# Delayed projects

# %%
delayed_projects = on_time[(on_time.on_time == False)].sort_values('target_GMLASubmitDate')
delayed_projects
# Out:
#      projectSizeId                 Project_Name    Phase  status  \
# 175            960                     fenix 7X  GMLA #2       1
# 19             785                       DGCN20  GMLA #3       1
# 137            936                    Edge 1040  GMLA #1       1
# 127            909     One Battery Bike Project  GMLA #3       1
# 190            968                   Descent G1  GMLA #1       1
# 176            960                     fenix 7X  GMLA #3       1
# 168            955  Varia Radar Camera (RCT715)  GMLA #2       1
# 211            979              vivomove "Lite"  GMLA #3       1
# 117            895                BMW MGU22-RSE  GMLA #3       1
# 350           1052            GPSMAP 9000 - 22"  GMLA #1       1
#
#                                           rejectReason  \
# 175                                               None
# 19   3.C-6: please find out what's difference of CP...
# 137                                               None
# 127     Please help to modify 3.C-5 issue description.
# 190  Strain gauge need to update the V3 PCB result ...
# 176  Revise 3.A-7 content (some 007- do not under 1...
# 168           update the mitigation plan of fail items
# 211                     some items are under confrimed
# 117                               3.E-4, 3.E-12 項目請修正。
# 350                      補充1.A-3 / 1.B-4 / 1.E-8的附件或註解
#
#                      kickOffMeetingDate          closeMeetingDate  \
# 175                                None 2020-12-30 00:00:00+08:00
# 19                                 None 2021-01-26 00:00:00+08:00
# 137                                None 2021-02-05 00:00:00+08:00
# 127                                None 2021-02-05 00:00:00+08:00
# 190                                None 2021-03-17 00:00:00+08:00
# 176  2021-03-07 16:00:00.0000000 +00:00 2021-05-10 00:00:00+08:00
# 168  2021-07-04 16:00:00.0000000 +00:00 2021-08-30 00:00:00+08:00
# 211  2021-06-30 16:00:00.0000000 +00:00 2021-09-13 00:00:00+08:00
# 117  2021-07-19 16:00:00.0000000 +00:00 2021-09-24 00:00:00+08:00
# 350                                None 2021-11-25 00:00:00+08:00
#
#                          GMLASubmitDate  IsByPass     target_GMLASubmitDate  \
# 175 2021-01-15 14:36:26.085105100+08:00         0 2021-01-12 00:00:00+08:00
# 19     2021-02-22 17:34:40.150389+08:00         0 2021-02-08 00:00:00+08:00
# 137 2021-02-19 17:29:48.395736400+08:00         0 2021-02-18 00:00:00+08:00
# 127 2021-03-04 15:19:42.207827800+08:00         0 2021-02-18 00:00:00+08:00
# 190 2021-04-03 08:24:22.410314400+08:00         0 2021-03-30 00:00:00+08:00
# 176 2021-05-24 11:20:06.622288900+08:00         0 2021-05-21 00:00:00+08:00
# 168 2021-09-23 16:20:34.945172800+08:00         0 2021-09-10 00:00:00+08:00
# 211 2021-09-27 22:15:16.189070600+08:00         0 2021-09-24 00:00:00+08:00
# 117 2021-10-19 13:51:42.345835500+08:00         0 2021-10-07 00:00:00+08:00
# 350 2021-12-09 15:38:58.259398100+08:00         0 2021-12-08 00:00:00+08:00
#
#      on_time  delay_but_rejected
# 175    False               False
# 19     False                True
# 137    False               False
# 127    False                True
# 190    False                True
# 176    False                True
# 168    False                True
# 211    False                True
# 117    False                True
# 350    False                True

# %%
actual_delayed_projects = on_time[(on_time.on_time == False) & (on_time.delay_but_rejected == False)].sort_values('target_GMLASubmitDate')
actual_delayed_projects
# Out:
#      projectSizeId Project_Name    Phase  status rejectReason  \
# 175            960     fenix 7X  GMLA #2       1         None
# 137            936    Edge 1040  GMLA #1       1         None
#
#     kickOffMeetingDate          closeMeetingDate  \
# 175               None 2020-12-30 00:00:00+08:00
# 137               None 2021-02-05 00:00:00+08:00
#
#                          GMLASubmitDate  IsByPass     target_GMLASubmitDate  \
# 175 2021-01-15 14:36:26.085105100+08:00         0 2021-01-12 00:00:00+08:00
# 137 2021-02-19 17:29:48.395736400+08:00         0 2021-02-18 00:00:00+08:00
#
#      on_time  delay_but_rejected
# 175    False               False
# 137    False               False

# %% [markdown]
# Resample

# %%
on_time_resampled = on_time.set_index('target_GMLASubmitDate').resample(rule='BM').agg({'Project_Name':'count','on_time':'sum','delay_but_rejected':'sum'})

# %%
on_time_resampled.rename(columns={'Project_Name':'total_projects','on_time':'on_time_projects','rejectReason':'rejcted_projects'}, inplace=True)

# %% [markdown]
# Convert datetime format

# %%
on_time_resampled.reset_index(inplace=True)

# %%
on_time_resampled['target_GMLASubmitDate'] = on_time_resampled['target_GMLASubmitDate'].dt.strftime('%Y-%m')

# %%
on_time_resampled = on_time_resampled.set_index('target_GMLASubmitDate')

# %%
on_time_resampled['on_time_rate'] = (100* (on_time_resampled.on_time_projects / on_time_resampled.total_projects)).round(2)

# %%
on_time_resampled['actual_on_time_rate'] = (100* ((on_time_resampled.on_time_projects+ on_time_resampled.delay_but_rejected) / on_time_resampled.total_projects)).round(2)

# %%
on_time_resampled
# Out:
#                        total_projects  on_time_projects  delay_but_rejected  \
# target_GMLASubmitDate
# 2021-01                             9                 8                   0
# 2021-02                             9                 6                   2
# 2021-03                            10                 9                   1
# 2021-04                            14                14                   0
# 2021-05                            10                 9                   1
# 2021-06                            13                13                   0
# 2021-07                             8                 8                   0
# 2021-08                             2                 2                   0
# 2021-09                             9                 7                   2
# 2021-10                            14                13                   1
# 2021-11                            12                12                   0
# 2021-12                            16                15                   1
# 2022-01                             7                 7                   0
# 2022-02                             7                 7                   0
# 2022-03                            12                12                   0
# 2022-04                            13                13                   0
# 2022-05                             8                 8                   0
# 2022-06                             4                 4                   0
#
#                        on_time_rate  actual_on_time_rate
# target_GMLASubmitDate
# 2021-01                       88.89                88.89
# 2021-02                       66.67                88.89
# 2021-03                       90.00               100.00
# 2021-04                      100.00               100.00
# 2021-05                       90.00               100.00
# 2021-06                      100.00               100.00
# 2021-07                      100.00               100.00
# 2021-08                      100.00               100.00
# 2021-09                       77.78               100.00
# 2021-10                       92.86               100.00
# 2021-11                      100.00               100.00
# 2021-12                       93.75               100.00
# 2022-01                      100.00               100.00
# 2022-02                      100.00               100.00
# 2022-03                      100.00               100.00
# 2022-04                      100.00               100.00
# 2022-05                      100.00               100.00
# 2022-06                      100.00               100.00

# %%
#on_time_resampled.to_excel(path+'\on_time.xlsx')

# %%
plt.figure(figsize=(20,7))
plt.grid()
sns.lineplot(data=on_time_resampled.on_time_rate, estimator=None, linewidth=3, alpha=0.5)
sns.lineplot(data=on_time_resampled.actual_on_time_rate, estimator=None, linewidth=3, alpha=0.8)
plt.legend(['on_time_rate','actual_on_time_rate'], loc='lower right')
plt.savefig(os.getcwd()+'\on_time_tread')
