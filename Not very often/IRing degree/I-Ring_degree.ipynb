# %%
import pandas as pd
import matplotlib.pyplot as plt
import manufacturing as mn

# %%
raw = pd.read_excel('I-Ring degree.xlsx')
raw.head()
# Out:
#        mk3s   f7s pro
# 0  0.334545 -0.086864
# 1 -0.262338 -0.128951
# 2 -0.033939 -0.093991
# 3 -0.156270 -0.316474
# 4 -0.202607 -0.064733

# %%
fig,ax = plt.subplots(figsize=(10, 8))
mn.ppk_plot(data=raw.mk3s, upper_specification_limit=0.5, lower_specification_limit=-0.5,figure=fig)

# %%
lower, upper = mn.suggest_specification_limits(data=raw.mk3s, sigma_level=3)

# %%
lower
# Out:
# -0.6383624901096212

# %%
upper
# Out:
# 0.6651088898491171

# %%
fig,ax = plt.subplots(figsize=(10, 8))
mn.ppk_plot(data=raw.mk3s, upper_specification_limit=upper, lower_specification_limit=lower,figure=fig)

# %%
fig,ax = plt.subplots(figsize=(10, 8))
mn.ppk_plot(data=raw['f7s pro_shift'], upper_specification_limit=0.5, lower_specification_limit=-0.5,figure=fig)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\wangcooper\Miniconda3\envs\workspace\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\wangcooper\Miniconda3\envs\workspace\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\wangcooper\Miniconda3\envs\workspace\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'f7s pro_shift'
#
# ...

# %%
raw['f7s pro_shift'] = raw['f7s pro'] - raw['f7s pro'].mean()

# %%
mn.suggest_specification_limits(data=raw['f7s pro_shift'])
# Out:
# (-0.5261140026464004, 0.5261140026464004)
