# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('all.xlsx')

# %%
df
# Out:
#      Reference  ItemNameType  SerialNumber  \
# 0    401004655         12434    3422062003
# 1    401005050         12434    3422062000
# 2    401005378         12434    3422062034
# 3    401005756         12434    3422061999
# 4    401006101         12434    3422062018
# ..         ...           ...           ...
# 531  403822567         12434    3425559216
# 532  403822985         12434    3425559236
# 533  405707886         12434    3422062319
# 534  405709836         12434    3422062319
# 535  405710597         12434    3422062319
#
#                             ProductName  Button1_F1  Button1_F2  \
# 0     Sub-Assy, Top Unit, Magna, Golfer        6.30        4.73
# 1     Sub-Assy, Top Unit, Magna, Golfer        6.19        4.64
# 2     Sub-Assy, Top Unit, Magna, Golfer        6.33        4.80
# 3     Sub-Assy, Top Unit, Magna, Golfer        6.37        4.68
# 4     Sub-Assy, Top Unit, Magna, Golfer        6.19        4.60
# ...

# %%
col_F1F2 = df.columns[df.columns.str.contains('F1|F2')]
col_F1F2
# Out:
# Index(['Button1_F1', 'Button1_F2', 'Button2_F1', 'Button2_F2', 'Button3_F1',
#        'Button3_F2', 'Button4_F1', 'Button4_F2', 'Button5_F1', 'Button5_F2'],
#       dtype='object')

# %%
col_click = df.columns[df.columns.str.contains('ClickRatio')]
col_click
# Out:
# Index(['Button1_ClickRatio', 'Button2_ClickRatio', 'Button3_ClickRatio',
#        'Button4_ClickRatio', 'Button5_ClickRatio'],
#       dtype='object')

# %%
goodsample = df[(df['Button1_ClickRatio']>0.2) & (df['Button2_ClickRatio']>0.2) & (df['Button3_ClickRatio']>0.2) & (df['Button4_ClickRatio']>0.2) & (df['Button5_ClickRatio']>0.2)]

# %%
goodsample[col_F1F2].describe()
# Out:
#        Button1_F1  Button1_F2  Button2_F1  Button2_F2  Button3_F1  Button3_F2  \
# count  402.000000  402.000000  402.000000  402.000000  402.000000  402.000000
# mean     6.409701    4.779900    6.450970    4.787139    6.730622    5.085846
# std      0.312344    0.325834    0.214656    0.199868    0.370282    0.300376
# min      5.930000    4.280000    6.060000    4.390000    5.980000    4.320000
# 25%      6.190000    4.540000    6.330000    4.670000    6.500000    4.880000
# 50%      6.290000    4.670000    6.420000    4.770000    6.645000    5.050000
# 75%      6.577500    4.927500    6.520000    4.880000    6.907500    5.270000
# max      7.450000    5.860000    7.590000    5.890000    8.910000    6.870000
#
#        Button4_F1  Button4_F2  Button5_F1  Button5_F2
# count  402.000000  402.000000  402.000000  402.000000
# mean     6.888010    5.194527    6.531567    4.921269
# std      0.596383    0.493956    0.255887    0.244722
# ...
