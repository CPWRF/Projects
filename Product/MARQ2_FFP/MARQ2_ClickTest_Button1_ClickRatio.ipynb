# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('clickRatiodata.xlsx')

# %%
df = df[df.ProductName.str.contains('MARQ|Magna')]
df.head()
# Out:
#     Reference  ItemNameType  StationID  UserName  SerialNumber  \
# 80  401004655         12434          0     18985    3422062003
# 81  401005050         12434          0     18985    3422062000
# 82  401005378         12434          0     18985    3422062034
# 83  401005756         12434          0     18985    3422061999
# 84  401006101         12434          0     18985    3422062018
#
#                           ProductName  Version  Item7           tDateTime  SO  \
# 80  Sub-Assy, Top Unit, Magna, Golfer      NaN   0.25 2022-07-22 11:02:12 NaN
# 81  Sub-Assy, Top Unit, Magna, Golfer      NaN   0.26 2022-07-22 11:03:53 NaN
# 82  Sub-Assy, Top Unit, Magna, Golfer      NaN   0.24 2022-07-22 11:05:37 NaN
# 83  Sub-Assy, Top Unit, Magna, Golfer      NaN   0.27 2022-07-22 11:07:28 NaN
# 84  Sub-Assy, Top Unit, Magna, Golfer      NaN   0.26 2022-07-22 11:09:01 NaN
#
#     Job_GPN  ClassCode
# 80      NaN        NaN
# 81      NaN        NaN
# 82      NaN        NaN
# 83      NaN        NaN
# 84      NaN        NaN

# %%
df_dup = df[df.duplicated(subset='SerialNumber',keep=False)].sort_values(['SerialNumber','tDateTime'])
df_dup.head()
# Out:
#      Reference  ItemNameType  StationID  UserName  SerialNumber  \
# 266  401366172         12434          0     18985    3422061904
# 288  401373516         12434          0     18985    3422061904
# 397  401483081         12434          0     26464    3422061904
# 271  401367832         12434          0     18985    3422061911
# 278  401370313         12434          0     18985    3422061911
#
#                             ProductName  Version  Item7           tDateTime  \
# 266  Sub-Assy, Top Unit, Magna, Aviator      NaN   0.20 2022-07-25 10:13:49
# 288  Sub-Assy, Top Unit, Magna, Aviator      NaN   0.21 2022-07-25 10:56:07
# 397  Sub-Assy, Top Unit, Magna, Aviator      NaN   0.21 2022-07-26 04:50:46
# 271  Sub-Assy, Top Unit, Magna, Aviator      NaN   0.14 2022-07-25 10:23:39
# 278  Sub-Assy, Top Unit, Magna, Aviator      NaN   0.17 2022-07-25 10:38:00
#
#      SO  Job_GPN  ClassCode
# 266 NaN      NaN        NaN
# 288 NaN      NaN        NaN
# 397 NaN      NaN        NaN
# 271 NaN      NaN        NaN
# 278 NaN      NaN        NaN

# %%
df_dup.drop_duplicates(subset='SerialNumber',keep='first')['ProductName'].value_counts()
# Out:
# Sub-Assy, Top Unit, Magna, Aviator      26
# Sub-Assy, Top Unit, Magna, Captain      11
# Sub-Assy, Top Unit, Magna, Golfer       10
# MARQ Athlete Gen 2, NA                  10
# Sub-Assy, Top Unit, Magna, Adventure     9
# Sub-Assy, Top Unit, Magna, Athlete       5
# MARQ Captain Gen 2, NA                   3
# MARQ Aviator Gen 2, NA                   2
# MARQ Golfer Gen 2, NA                    1
# MARQ Adventurer Gen 2, NA                1
# Name: ProductName, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(data=df_dup.drop_duplicates(subset='SerialNumber',keep='first'),x='Item7', bw_method=0.3)
sns.kdeplot(data=df_dup.drop_duplicates(subset='SerialNumber',keep='last'),x='Item7',bw_method=0.3)
plt.legend(labels=['First click', 'Last(~3) click'])
plt.axvline(0.2, color='r', linestyle='--')
plt.title('Click_Ratio')
#plt.savefig('Click_Ratio' ,bbox_inches = "tight", facecolor='white', transparent=False, dpi=300)
