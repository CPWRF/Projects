# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('clickRatio_stroke.xlsx')
df.sort_values('tDateTime', inplace=True)
df.tDateTime = df.tDateTime.dt.date

# %%
df_d = df.drop_duplicates(subset='SerialNumber', keep='last')

# %%
click_NG = df[(df.iloc[:,4:9] <0.2).any(axis=1)].sort_values('SerialNumber')

# %%
click_NG.describe().iloc[:,3:8].round(2)#.to_excel('clickRatioNG_Asia_describe.xlsx')
# Out:
#        Button1_ClickRatio  Button2_ClickRatio  Button3_ClickRatio  \
# count              110.00              110.00              110.00
# mean                 0.21                0.24                0.21
# std                  0.05                0.05                0.05
# min                  0.00                0.00                0.00
# 25%                  0.18                0.25                0.19
# 50%                  0.20                0.26                0.22
# 75%                  0.25                0.27                0.25
# max                  0.29                0.29                0.28
#
#        Button4_ClickRatio  Button5_ClickRatio
# count              110.00              110.00
# mean                 0.20                0.24
# std                  0.08                0.04
# min                  0.00                0.00
# 25%                  0.18                0.24
# 50%                  0.22                0.25
# ...

# %%
stroke_NG = df[((df.iloc[:,9:14]<0.2) | (df.iloc[:,9:14]>0.5)).any(axis=1)]

# %%
plt.figure(figsize=(20,10))
sns.stripplot(data=df_d, x='tDateTime', y='Button1_Stroke')
plt.axhline(0.2, ls='--')
plt.axhline(0.5, ls='--')

# %%
plt.figure(figsize=(20,10))
sns.stripplot(data=df_d, x='tDateTime', y='Button2_Stroke')
plt.axhline(0.2, ls='--')
plt.axhline(0.5, ls='--')

# %%
plt.figure(figsize=(20,10))
sns.stripplot(data=df_d, x='tDateTime', y='Button3_Stroke')
plt.axhline(0.2, ls='--')
plt.axhline(0.5, ls='--')

# %%
plt.figure(figsize=(20,10))
sns.stripplot(data=df_d, x='tDateTime', y='Button4_Stroke')
plt.axhline(0.2, ls='--')
plt.axhline(0.5, ls='--')
plt.savefig('Button4_Stroke_last_stripplot',bbox_inches = "tight", facecolor='white', transparent=False, dpi=300)

# %%
plt.figure(figsize=(20,10))
sns.stripplot(data=df_d, x='tDateTime', y='Button5_Stroke')
plt.axhline(0.2, ls='--')
plt.axhline(0.5, ls='--')
