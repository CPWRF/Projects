# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('ALSdata.xlsx')
df.tDateTime = pd.to_datetime(df.tDateTime, utc=True).dt.tz_convert('Asia/Taipei')
df = df[df.Item33St.isin([0,1])]

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df[df.Item33>7000], x='Item33', hue='Item33St', bins=40)
plt.axvline(10000, color='blue', linestyle='--') #Test start in 07-22 10:51
plt.axvline(11000, color='blue', linestyle='--') # Move USL to 11000 from 10000 in 07-22 13:27
plt.axvline(12000, color='r', linestyle='--') # Move USL to 12000 from 11000 in 08-01 10:18

# %%
#df_9900 = df[df.Item33 > 9900].sort_values('tDateTime')
#df_9900

# %%
#plt.figure(figsize=(10,8))
#sns.histplot(data=df_9900, x='Item33', hue='Item33St', alpha=0.5)
#plt.axvline(10000, color='blue', linestyle='--')
#plt.axvline(11000, color='r', linestyle='--') # Move USL to 11000 from 10000 in 07-22 13:27. Test start in 07-22 10:51

# %%
len(df[df.Item33.between(10000,11000) & (df.Item33St==0)].sort_values('tDateTime'))
# Out:
# 21

# %%
df[df.Item33.between(10000,11000) & (df.Item33St==0)].sort_values('tDateTime')
# Out:
#      Reference  ItemNameType  StationID  UserName  SerialNumber  \
# 409  400920940         17466          1     20727    3422062073
# 407  400928645         17466          2     20727    3422062073
# 404  400929394         17466          1     20727    3422062070
# 402  400929798         17466          2     20727    3422062070
# 400  400930142         17466          1     20727    3422062048
# 396  400931159         17466          2     20727    3422062034
# 393  400931568         17466          1     20727    3422062034
# 387  400932233         17466          2     20727    3422062112
# 0    400932773         17466          1     20727    3422062112
# 161  400932960         17466          2     20727    3422062088
# 159  400933245         17466          1     20727    3422062088
# 155  400934045         17466          2     20727    3422062100
# 154  400934050         17466          1     20727    3422062098
# 384  400934225         17466          1     20727    3422062100
# 383  400934238         17466          2     20727    3422062098
# 379  400935825         17466          2      3622    3422062093
# 152  400937023         17466          1      3622    3422062093
# 151  400937421         17466          2      3622    3422062101
# 150  400937422         17466          1      3622    3422062083
# 373  400938333         17466          1      3622    3422062101
# 372  400938345         17466          2      3622    3422062083
#
#           ProductName  Version  Item33  Item33St                 tDateTime  \
# 409  MARQ GEN2 V09.10      9.1   10360         0 2022-07-22 10:59:01+08:00
# 407  MARQ GEN2 V09.10      9.1   10120         0 2022-07-22 11:42:18+08:00
# 404  MARQ GEN2 V09.10      9.1   10420         0 2022-07-22 11:46:46+08:00
# 402  MARQ GEN2 V09.10      9.1   10100         0 2022-07-22 11:49:03+08:00
# 400  MARQ GEN2 V09.10      9.1   10350         0 2022-07-22 11:51:08+08:00
# 396  MARQ GEN2 V09.10      9.1   10120         0 2022-07-22 11:57:12+08:00
# 393  MARQ GEN2 V09.10      9.1   10280         0 2022-07-22 12:00:23+08:00
# 387  MARQ GEN2 V09.10      9.1   10600         0 2022-07-22 12:11:15+08:00
