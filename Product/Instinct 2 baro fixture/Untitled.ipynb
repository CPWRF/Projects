# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('baro.xlsx', index_col=8 ,parse_dates=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1967 entries, 2022-02-14 07:05:44+00:00 to 2022-02-14 22:15:25+00:00
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fixtureID1  1967 non-null   int64
#  1   fixtureID2  1967 non-null   int64
#  2   esn         1967 non-null   int64
#  3   pass        1967 non-null   bool
#  4   fail_item   1967 non-null   int64
#  5   station_id  1967 non-null   int64
#  6   value       1967 non-null   float64
#  7   status      1967 non-null   int64
# dtypes: bool(1), float64(1), int64(6)
# memory usage: 124.9 KB

# %%
df[df['value']==-999]['fixtureID2'].value_counts()
# Out:
# 6    34
# 4    32
# 2     5
# 3     1
# 7     1
# Name: fixtureID2, dtype: int64

# %%
df_fix6 = df[(df['fixtureID2']==6)]
df_fix4 = df[(df['fixtureID2']==4)]

# %%
df_fix6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 259 entries, 2022-02-14 07:06:46+00:00 to 2022-02-14 19:48:20+00:00
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fixtureID1  259 non-null    int64
#  1   fixtureID2  259 non-null    int64
#  2   esn         259 non-null    int64
#  3   pass        259 non-null    bool
#  4   fail_item   259 non-null    int64
#  5   station_id  259 non-null    int64
#  6   value       259 non-null    float64
#  7   status      259 non-null    int64
# dtypes: bool(1), float64(1), int64(6)
# memory usage: 16.4 KB

# %%
df_fix6.head()
# Out:
#                            fixtureID1  fixtureID2         esn   pass  \
# date_time
# 2022-02-14 07:06:46+00:00   110547610           6  3408632004  False
# 2022-02-14 07:08:21+00:00   110547610           6  3408632001  False
# 2022-02-14 07:22:34+00:00   110547610           6  3408631976   True
# 2022-02-14 07:24:33+00:00   110547610           6  3408631966  False
# 2022-02-14 07:35:12+00:00   110547600           6  3408631937  False
#
#                            fail_item  station_id      value  status
# date_time
# 2022-02-14 07:06:46+00:00          6           4 -999.00000       5
# 2022-02-14 07:08:21+00:00          6           4 -999.00000       5
# 2022-02-14 07:22:34+00:00          0           4   18.95313       1
# 2022-02-14 07:24:33+00:00          6           4 -999.00000       5
# 2022-02-14 07:35:12+00:00          6           5 -999.00000       5

# %%
df_fix6.loc['2022-02-14','2022-02-14']['value']
# Out:
# C:\Users\wangcooper\Anaconda3\lib\site-packages\pandas\core\generic.py:3724: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   return self[key]
# date_time
# 2022-02-14 07:06:46+00:00   -999.00000
# 2022-02-14 07:08:21+00:00   -999.00000
# 2022-02-14 07:22:34+00:00     18.95313
# 2022-02-14 07:24:33+00:00   -999.00000
# 2022-02-14 07:35:12+00:00   -999.00000
#                                ...
# 2022-02-14 18:00:04+00:00   -999.00000
# 2022-02-14 18:02:34+00:00      0.00000
# 2022-02-14 19:02:41+00:00   -999.00000
# 2022-02-14 19:47:11+00:00      0.00000
# 2022-02-14 19:48:20+00:00   -999.00000
# Name: value, Length: 259, dtype: float64

# %%
plt.figure(figsize=(30,10))
df_fix6.resample(rule='min').mean()['value'].plot(xlim=['2022-02-14 12:00:00','2022-02-14 22:00:00'])
plt.legend()

# %%
plt.figure(figsize=(30,10))
df_fix4.resample(rule='min').mean()['value'].plot()
# Out:
# <AxesSubplot:xlabel='date_time'>
