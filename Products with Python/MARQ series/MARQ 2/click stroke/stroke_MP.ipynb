# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway

# %%
stroke = pd.read_excel('stroke_MP.xlsx')

# %%
stroke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1925 entries, 0 to 1924
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SerialNumber    1925 non-null   object
#  1   Button1_Stroke  1925 non-null   float64
#  2   Button2_Stroke  1925 non-null   float64
#  3   Button3_Stroke  1925 non-null   float64
#  4   Button4_Stroke  1925 non-null   float64
#  5   Button5_Stroke  1925 non-null   float64
#  6   tDateTime       1925 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 105.4+ KB

# %%
plt.style.use('fivethirtyeight')

# %%
#stroke_greater0 = stroke.replace(0, None).dropna(axis=0)

# %%
#f_oneway(stroke_greater0.Button1_Stroke, stroke_greater0.Button2_Stroke, stroke_greater0.Button3_Stroke, stroke_greater0.Button4_Stroke, stroke_greater0.Button5_Stroke)

# %%
plt.figure(dpi=300, figsize=(10,6))
sns.stripplot(data=stroke.iloc[:,1:6])
plt.axhline(0.65, color='blue', ls='--')
plt.axhline(0.6, color='blue', ls='--')
plt.axhline(0.5, color='red', ls='--')
plt.axhline(0.2, color='red', ls='--')
plt.title('All results with retry')
# Out:
# Text(0.5, 1.0, 'All results with retry')

# %%
stroke_dropdup = stroke.sort_values('tDateTime').drop_duplicates(subset='SerialNumber', keep='last')

# %%
stroke_dropdup

# %%
plt.figure(dpi=300, figsize=(10,6))
sns.stripplot(data=stroke_dropdup.iloc[:,1:6])
plt.axhline(0.55, color='blue', ls='--')
plt.axhline(0.5, color='red', ls='--')
plt.axhline(0.2, color='red', ls='--')
plt.title('Last results for each ESN')
plt.text(s='0.55', y=0.56, x=-0.5, color='blue')
# Out:
# Text(-0.5, 0.56, '0.55')

# %%
stroke_dropdup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1400 entries, 0 to 1924
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SerialNumber    1400 non-null   object
#  1   Button1_Stroke  1400 non-null   float64
#  2   Button2_Stroke  1400 non-null   float64
#  3   Button3_Stroke  1400 non-null   float64
#  4   Button4_Stroke  1400 non-null   float64
#  5   Button5_Stroke  1400 non-null   float64
#  6   tDateTime       1400 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 87.5+ KB

# %%
stroke_dropdup[stroke_dropdup.iloc[:,1:6]>0.5].dropna(thresh=1)
# Out:
#      SerialNumber  Button1_Stroke  Button2_Stroke  Button3_Stroke  \
# 5             NaN             NaN            0.51             NaN
# 37            NaN            0.53             NaN             NaN
# 42            NaN             NaN            0.58             NaN
# 44            NaN             NaN            0.57             NaN
# 351           NaN            0.53             NaN             NaN
# ...           ...             ...             ...             ...
# 1867          NaN             NaN            0.53             NaN
# 1868          NaN             NaN            0.53             NaN
# 1869          NaN             NaN             NaN            0.51
# 1871          NaN             NaN             NaN             NaN
# 1885          NaN             NaN            0.54             NaN
#
#       Button4_Stroke  Button5_Stroke tDateTime
# 5                NaN             NaN       NaT
# 37               NaN             NaN       NaT
# ...

# %%
stroke_dropdup[stroke_dropdup.iloc[:,1:6]>0.55].dropna(thresh=1)
# Out:
#      SerialNumber  Button1_Stroke  Button2_Stroke  Button3_Stroke  \
# 42            NaN             NaN            0.58             NaN
# 44            NaN             NaN            0.57             NaN
# 1061          NaN             NaN             NaN             NaN
# 1790          NaN             NaN             NaN             NaN
#
#       Button4_Stroke  Button5_Stroke tDateTime
# 42               NaN             NaN       NaT
# 44               NaN             NaN       NaT
# 1061            0.59             NaN       NaT
# 1790             NaN            0.57       NaT
