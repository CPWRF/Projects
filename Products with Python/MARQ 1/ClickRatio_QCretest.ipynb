# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
click = pd.read_excel('ClickRatio_QCretest.xlsx')
click.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tDateTime     525 non-null    datetime64[ns]
#  1   SerialNumber  525 non-null    int64
#  2   Result        525 non-null    int64
#  3   FailItem      525 non-null    int64
#  4   UserName      525 non-null    int64
#  5   Btn1_CR       525 non-null    float64
#  6   Btn2_CR       525 non-null    float64
#  7   Btn3_CR       525 non-null    float64
#  8   Btn4_CR       525 non-null    float64
#  9   Btn5_CR       525 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(4)
# memory usage: 41.1 KB

# %%
plt.style.use('fivethirtyeight')

# %%
click.sort_values(['tDateTime','SerialNumber'], inplace=True)

# %%
def less(x):
    return f"color: {'red'if x < 0.18 else x}"

# %%
click2 = click[click.Result == 0]
click2.iloc[:,5:].style.applymap(less)
# Out:
# <style type="text/css">
# #T_ce273_row0_col0, #T_ce273_row9_col0 {
#   color: 0.288;
# }
# #T_ce273_row0_col1, #T_ce273_row1_col0 {
#   color: 0.279;
# }
# #T_ce273_row0_col2, #T_ce273_row0_col4 {
#   color: 0.292;
# }
# #T_ce273_row0_col3, #T_ce273_row1_col4, #T_ce273_row2_col4, #T_ce273_row4_col1, #T_ce273_row4_col2, #T_ce273_row4_col3, #T_ce273_row4_col4, #T_ce273_row5_col1, #T_ce273_row6_col0, #T_ce273_row7_col1, #T_ce273_row8_col3, #T_ce273_row9_col2, #T_ce273_row10_col2, #T_ce273_row11_col0, #T_ce273_row12_col3, #T_ce273_row13_col3, #T_ce273_row15_col2, #T_ce273_row18_col0, #T_ce273_row19_col0, #T_ce273_row21_col2, #T_ce273_row22_col1 {
#   color: red;
# }
# #T_ce273_row1_col1, #T_ce273_row5_col3, #T_ce273_row10_col4 {
#   color: 0.262;
# }
# #T_ce273_row1_col2, #T_ce273_row1_col3, #T_ce273_row4_col0, #T_ce273_row9_col3, #T_ce273_row11_col4, #T_ce273_row12_col0, #T_ce273_row19_col2, #T_ce273_row19_col4, #T_ce273_row22_col0 {
#   color: 0.246;
# }
# #T_ce273_row2_col0 {
# ...

# %%
click.FailItem.value_counts()
# Out:
# 0     502
# 27      7
# 37      6
# 47      4
# 7       4
# 17      2
# Name: FailItem, dtype: int64
