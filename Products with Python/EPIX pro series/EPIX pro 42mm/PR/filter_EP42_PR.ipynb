# %%
import pandas as pd

# %%
raw = pd.read_excel('Epix42_PR_45degree.xlsx')

# %%
raw.sample(5)
# Out:
#     Process  ItemName Type            Process Type  Item  \
# 144    ASSY          17800             Epix_Pro_CT    55
# 160    ASSY          17802            Epix_Pro_FT1   176
# 27     ASSY          17812  Epix_Pro_ProdScan_Pack     9
# 89     ASSY          17812  Epix_Pro_ProdScan_Pack    54
# 215     SMT          10570     BI_After_UseCharger     4
#
#                                ItemName Count/Count ESN  Retest%
# 144   Barometer Temperature non_recheck           3/623     0.48
# 160  Internal Light Pollution (ILP) Ch8           2/587     0.34
# 27                Check Battery Voltage          23/296     7.77
# 89              Check Wifi Country Code           3/296     1.01
# 215                 功能檢查|Check Function           1/611     0.16

# %%
ProcessTypeBlackList = 'Pack|Click|RabbitCard|EasyCard|DeleteBundle|ProdScan|FileCopyer'
ItemNameBlackList = 'ESN|Check ProductionMap|Fixture ID'

# %%
def filter(raw):
    return(raw
    .rename(columns = lambda name : name.replace(" ",'').replace('/','').replace('%',''))
    .astype({'ItemNameType':'category','ProcessType':'category','Item':'category','ItemName':'category'})
    .assign(CountESN = lambda df : df.CountCountESN.str.split('/').str[1].astype('int16'))
    .query("~ProcessType.str.contains(@ProcessTypeBlackList) and ~ItemName.str.contains(@ItemNameBlackList)")
    # .CountESN.quantile(0.03)
    .query("CountESN > CountESN.quantile(0.05)")
    .query("Retest >= Retest.mean()")
    # .Retest.mean()
    )
filter(raw)
# Out:
#    Process ItemNameType            ProcessType Item  \
# 7     ASSY        17196        Epix_pro_42_M_B  212
# 8     ASSY        17820        Epix_Pro_ECG_FT  293
# 9     ASSY        17820        Epix_Pro_ECG_FT  285
# 10    ASSY        18547  Epix_Pro_MultiUpdater   26
# 11    ASSY        17859        Epix_Pro_ATE_TI   88
# 13    ASSY        17808       Epix_Pro_GSensor   17
# 14    ASSY        17858       Epix_Pro_ECG_ATE   30
# 18    ASSY        17886         Epix_pro_RTESN   57
# 19    ASSY        17858       Epix_Pro_ECG_ATE   15
# 20    ASSY        17858       Epix_Pro_ECG_ATE   15
# 22    ASSY        17803           Epix_Pro_FT2   36
# 25    ASSY        17801            Epix_Pro_HT   42
# 28    ASSY        17859        Epix_Pro_ATE_TI   41
# 29    ASSY        17802           Epix_Pro_FT1  167
# 33    ASSY         8837         Airtight_table  118
# 34    ASSY        17803           Epix_Pro_FT2   62
# 35    ASSY        17803           Epix_Pro_FT2   38
# 36    ASSY        17798       Epix_Pro_AutoATE  141
# 37    ASSY        17808       Epix_Pro_GSensor    6
# 41    ASSY        17820        Epix_Pro_ECG_FT  299
# 42    ASSY        17803           Epix_Pro_FT2   28
# 43    ASSY         8837         Airtight_table  124
# 44    ASSY        17886         Epix_pro_RTESN   75
# 47    ASSY        17798       Epix_Pro_AutoATE   28
# 50    ASSY        17802           Epix_Pro_FT1  130
# 51    ASSY         8837         Airtight_table  117
# 52    ASSY        17802           Epix_Pro_FT1   31
# 53    ASSY        17808       Epix_Pro_GSensor   37
# 54    ASSY        17800            Epix_Pro_CT   57
# 55    ASSY        18547  Epix_Pro_MultiUpdater    4
# 58    ASSY        17808       Epix_Pro_GSensor   33
# 60    ASSY        17822           Epix_Pro_ALS   15
# 61    ASSY        17859        Epix_Pro_ATE_TI   34
# 65    ASSY        17858       Epix_Pro_ECG_ATE   20
# 66    ASSY        17858       Epix_Pro_ECG_ATE   20
#
#                                            ItemName CountCountESN  Retest  \
# 7                                  (4000Hz) dBSPL+A        74/450   16.44
# 8                           ECG RLD 10Hz 500mV Test        73/456   16.01
# 9                               ECG impedance short        70/456   15.35
# 10                                 Check Boot Block        91/646   14.09
# 11                       AFE Power Consumption data       105/765   13.73
# 13                                      Calibration        41/320   12.81
# 14                         Motor Resonant Frequency        89/766   11.62
# 18                          光學心跳模組檢查|Check OHRM LED        66/629   10.49
# 19                                    Check 1907IOP        79/766   10.31
# 20                                    Check 1907IOP        79/766   10.31
# 22             Power Box Sampling BL on normal(Avg)        44/437   10.07
# 25                                    GPS_L5 by ref        51/619    8.24
# 28                            Barometer Temperature        53/765    6.93
# 29               Analog Front End BIST - Revision 1        40/587    6.81
# 33                                        連續斜率異常_負壓        33/610    5.41
# 34  外部電流(反插)|VEXT Current(Reverse) BL&OHR On - EP51        23/437    5.26
# 35              ANT_power 2450MHz BY REF (sapphire)        22/437    5.03
# 36      馬達共振頻率(EP42)|Motor Resonant Frequency(EP42)        32/645    4.96
# 37                                            Z min        15/320    4.69
# 41                                 ECG 2mv 5Hz Test        18/456    3.95
# 42                         與 AP 連線|(WiFi) Access AP        17/437    3.89
# 43                                        連續斜率異常_正壓        23/610    3.77
# 44                               Check ECG 1907 IOP        23/629    3.66
# 47                              蜂鳴器V28|Beeper V28P0        22/645    3.41
# 50                                  006J Comparison        19/587    3.24
# 51                                    變形量絕對值超出規格_負壓        18/610    2.95
# 52                            GPS_ (L1 + L5) by ref        17/587    2.90
# 53                             電池電壓|Battery Voltage         9/320    2.81
# 54                          Check Wifi Country Code        17/623    2.73
# 55                            USB 連線|USB Connection        17/646    2.63
# 58                                           Diff Y         8/320    2.50
# 60                   Temperature Sensor Temperature        12/562    2.14
# 61                       AFE Power Consumption Test        16/765    2.09
# 65                                 ECG 2mv 5Hz Test        14/766    1.83
# 66                                 ECG 2mv 5Hz Test        14/766    1.83
#
#     CountESN
# 7        450
# 8        456
# 9        456
# 10       646
# 11       765
# 13       320
# 14       766
# 18       629
# 19       766
# 20       766
# 22       437
# 25       619
# 28       765
# 29       587
# 33       610
# 34       437
# 35       437
# 36       645
# 37       320
# 41       456
# 42       437
# 43       610
# 44       629
# 47       645
# 50       587
# 51       610
# 52       587
# 53       320
# 54       623
# 55       646
# 58       320
# 60       562
# 61       765
# 65       766
# 66       766

# %%
filter(raw).to_excel('tweak_EP42_PR_45degree.xlsx',index=False)
