# %%
import pandas as pd

# %%
raw = pd.read_excel('EP51_45degree_FFP.xlsx',sheet_name='Test Result')

# %%
raw.sample(3)
# Out:
#      ItemName Type      Process Type  Item                     ItemName  \
# 178          17798  Epix_Pro_AutoATE    67                Motor voltage
# 164          17802      Epix_Pro_FT1    56        M-Sensor BIST Overall
# 117          17800       Epix_Pro_CT    10  Is ESN check in non_recheck
#
#     Count/Count ESN  Retest%  Comment
# 178           1/535     0.19      NaN
# 164           1/453     0.22      NaN
# 117           2/455     0.44      NaN

# %%
ProcessTypeBlackList = 'Pack|Click|RabbitCard|EasyCard|DeleteBundle|ProdScan|FileCopyer'
ItemNameBlackList = 'ESN|Check ProductionMap|Fixture ID'

# %%
def filter(raw):
    return(raw
    .rename(columns = lambda name : name.replace(" ",'').replace('/','').replace('%',''))
    .sort_values('Retest', ascending=False)
    .astype({'ItemNameType':'category','ProcessType':'category','Item':'category','ItemName':'category'})
    .assign(CountESN = lambda df : df.CountCountESN.str.split('/').str[1].astype('int16'))
    .query("~ProcessType.str.contains(@ProcessTypeBlackList) and ~ItemName.str.contains(@ItemNameBlackList)")
    # .CountESN.quantile(0.03)
    .query("CountESN > CountESN.quantile(0.05)")
    .query("Retest >= Retest.mean()")
    # .Retest.mean()
    )
filter(raw)
# Out:
#    ItemNameType       ProcessType Item  \
# 2         17859   Epix_Pro_ATE_TI   88
# 3         17859   Epix_Pro_ATE_TI   41
# 4         17800       Epix_Pro_CT   60
# 5          8837    Airtight_table  129
# 6         17803      Epix_Pro_FT2   38
# 8         17858  Epix_Pro_ECG_ATE   30
# 9         17801       Epix_Pro_HT   42
# 10         8837    Airtight_table  118
# 11        17801       Epix_Pro_HT   17
# 12        17802      Epix_Pro_FT1   13
# 14        17820   Epix_Pro_ECG_FT  285
# 16        17801       Epix_Pro_HT    8
# 17        17820   Epix_Pro_ECG_FT  293
# 18        17798  Epix_Pro_AutoATE   39
# 19        17802      Epix_Pro_FT1   31
# 20        17859   Epix_Pro_ATE_TI   46
# 21        17798  Epix_Pro_AutoATE   71
# 22        17822      Epix_Pro_ALS   15
# 23        17809     Epix_Pro_Baro   11
# 24        17803      Epix_Pro_FT2  247
# 25        17802      Epix_Pro_FT1  167
# 26        17822      Epix_Pro_ALS   19
# 28        17803      Epix_Pro_FT2   62
# 29         8837    Airtight_table  114
# 30         8837    Airtight_table  117
# 31        17802      Epix_Pro_FT1    9
# 32        17886    Epix_pro_RTESN   58
# 33        17803      Epix_Pro_FT2   25
# 34        17886    Epix_pro_RTESN    6
# 35        17803      Epix_Pro_FT2   35
# 36         8837    Airtight_table  124
# 37        17802      Epix_Pro_FT1  195
# 38        17801       Epix_Pro_HT   41
# 41        17802      Epix_Pro_FT1  180
# 42        17798  Epix_Pro_AutoATE   22
#
#                                     ItemName CountCountESN  Retest  Comment  \
# 2                 AFE Power Consumption data       128/529   24.20      NaN
# 3                      Barometer Temperature        93/529   17.58      NaN
# 4                      GPS_ (L1 + L5) by ref        68/455   14.95      NaN
# 5                              變形量絕對值超出規格_常壓        54/453   11.92      NaN
# 6        ANT_power 2450MHz BY REF (sapphire)        51/448   11.38      NaN
# 8                   Motor Resonant Frequency        55/540   10.19      NaN
# 9                              GPS_L5 by ref        41/455    9.01      NaN
# 10                                 連續斜率異常_負壓        29/453    6.40      NaN
# 11                   Baro Raw (BIST Average)        25/455    5.49      NaN
# 12                                       RAM        23/453    5.08      NaN
# 14                       ECG impedance short        18/445    4.04      NaN
# 16                      電池電壓|Battery Voltage        16/455    3.52      NaN
# 17                   ECG RLD 10Hz 500mV Test        15/445    3.37      NaN
# 18                  電池溫度|Battery Temperature        18/535    3.36      NaN
# 19                     GPS_ (L1 + L5) by ref        15/453    3.31      NaN
# 20            Temperature Sensor Temperature        17/529    3.21      NaN
# 21         Conducted GPS Sensitivity C/No L5        16/535    2.99      NaN
# 22            Temperature Sensor Temperature        13/444    2.93      NaN
# 23                  0.5 ATM diff with golden        13/443    2.93      NaN
# 24                       Manifest Event Test        13/448    2.90      NaN
# 25        Analog Front End BIST - Revision 1        13/453    2.87      NaN
# 26       Temperature Sensor Temperature diff        12/444    2.70      NaN
# 28  外部電流(反插)|VEXT Current(Reverse) BL&OHR On        11/448    2.46      NaN
# 29                                Final Fail        11/453    2.43      NaN
# 30                             變形量絕對值超出規格_負壓        11/453    2.43      NaN
# 31                      電池電壓|Battery Voltage        11/453    2.43      NaN
# 32                          Baro Temperature        11/457    2.41      NaN
# 33                        按鍵測試|Keyboard Test         9/448    2.01      NaN
# 34        手電筒白光檢查檢查| Check Flashlight(White)         9/457    1.97      NaN
# 35                         ANT_power 2450MHz         8/448    1.79      NaN
# 36                                 連續斜率異常_正壓         8/453    1.77      NaN
# 37     充電電流(charging)|VEXT Current(charging)         8/453    1.77      NaN
# 38                                    GPS_L5         8/455    1.76      NaN
# 41       Internal Light Pollution (ILP) Ch12         7/453    1.55      NaN
# 42                USB連線(1)|USB Connection(1)         8/535    1.50      NaN
#
#     CountESN
# 2        529
# 3        529
# 4        455
# 5        453
# 6        448
# 8        540
# 9        455
# 10       453
# 11       455
# 12       453
# 14       445
# 16       455
# 17       445
# 18       535
# 19       453
# 20       529
# 21       535
# 22       444
# 23       443
# 24       448
# 25       453
# 26       444
# 28       448
# 29       453
# 30       453
# 31       453
# 32       457
# 33       448
# 34       457
# 35       448
# 36       453
# 37       453
# 38       455
# 41       453
# 42       535

# %%
# filter(raw).to_excel('tweak_EP51_PR_45degree.xlsx', index=False)
