# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
assy = pd.read_excel('raw.xlsx', sheet_name='Raw data (ASSY)')
ohrm = pd.read_excel('raw.xlsx', sheet_name='Raw data (OHRM)')

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# OHRM AFE Power Consumption data 180/601 29.95%

# %%
plt.figure(dpi=200)
sns.histplot(ohrm[(ohrm.ItemNameType == 17859) & (ohrm.failitem.isin([0,88]))], x='AFE Power Consumption data(Item88)', hue='Result', hue_order=[True,False])
# Out:
# <AxesSubplot:xlabel='AFE Power Consumption data(Item88)', ylabel='Count'>

# %% [markdown]
# FT2 ANT_power 2450MHz BY REF (sapphire) (F7sPro) 133/517 25.73%

# %%
plt.figure(dpi=200)
sns.histplot(assy[(assy.ItemNameType == 17937) & (assy.failitem.isin([0,21]))], x='ANT_power 2450MHz BY REF (sapphire) (F7sPro)(item21)', hue='Result', hue_order=[True,False])

# Golden sample問題，現在是用EP42的golden測試。EP42與F7差不多，所以差異不大
# Out:
# <AxesSubplot:xlabel='ANT_power 2450MHz BY REF (sapphire) (F7sPro)(item21)', ylabel='Count'>

# %% [markdown]
# ATE-ECG 2mv 5Hz Test 98/599 16.36%

# %%
ecg = ohrm[(ohrm.ItemNameType == 17858) & (ohrm.failitem.isin([0,20]))]

# %%
ecg['ECG 2mv 5HZ TEST(Item20)_clip'] = ecg['ECG 2mv 5HZ TEST(Item20)'].clip(lower = -2)
# Out:
# C:\Users\wangcooper\AppData\Local\Temp\ipykernel_6420\658132255.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ecg['ECG 2mv 5HZ TEST(Item20)_clip'] = ecg['ECG 2mv 5HZ TEST(Item20)'].clip(lower = -2)

# %%
plt.figure(dpi=200)
sns.histplot(ecg, x='ECG 2mv 5HZ TEST(Item20)_clip', hue='Result', hue_order=[True,False])
plt.title('Clip -999 to -2')
# Out:
# Text(0.5, 1.0, 'Clip -999 to -2')

# %% [markdown]
# ATE - Motor Resonant Frequency 92/599 15.36%

# %%
motor = ohrm[(ohrm.ItemNameType == 17858) & (ohrm.failitem.isin([0,30]))]

# %%
motor['Motor Resonant Frequency(Item30)_clip'] = motor['Motor Resonant Frequency(Item30)'].clip(lower=-2)
# Out:
# C:\Users\wangcooper\AppData\Local\Temp\ipykernel_6420\2641663309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   motor['Motor Resonant Frequency(Item30)_clip'] = motor['Motor Resonant Frequency(Item30)'].clip(lower=-2)

# %%
plt.figure(dpi=200)
sns.histplot(motor, x='Motor Resonant Frequency(Item30)_clip', hue='Result', hue_order=[True,False])
plt.title('Clip -999 to -2')

#fixture ID3有高重測?
# Out:
# Text(0.5, 1.0, 'Clip -999 to -2')

# %% [markdown]
# Barometer Temperature 79/601 13.14%

# %%
baro = ohrm[(ohrm.ItemNameType == 17859) & (ohrm.failitem.isin([0,41]))]

# %%
baro['Barometer Temperature(Item41)_clip'] = baro['Barometer Temperature(Item41)'].clip(lower=-2)
# Out:
# C:\Users\wangcooper\AppData\Local\Temp\ipykernel_6420\4012162166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   baro['Barometer Temperature(Item41)_clip'] = baro['Barometer Temperature(Item41)'].clip(lower=-2)

# %%
plt.figure(dpi=200)
sns.histplot(baro, x='Barometer Temperature(Item41)_clip', hue='Result', hue_order=[True,False])
plt.title('Clip -999 to -2')
# Out:
# Text(0.5, 1.0, 'Clip -999 to -2')

# %%
baro['Barometer Temperature(Item41)_clip'].describe().to_frame()
# Out:
#        Barometer Temperature(Item41)_clip
# count                          682.000000
# mean                            21.692839
# std                             11.486135
# min                             -2.000000
# 25%                             23.730467
# 50%                             24.179690
# 75%                             24.599607
# max                            168.195300

# %% [markdown]
# FT2 ECG impedance short 52/499 10.42%

# %%
ft_ecg = assy[(assy.ItemNameType == 17940) & (assy.failitem.isin([0,207]))]
ft_ecg['ECG impedance short(item207)'].describe().to_frame()
# Out:
#        ECG impedance short(item207)
# count                  6.280000e+02
# mean                   2.023639e+05
# std                    2.199602e+05
# min                   -9.990000e+02
# 25%                    1.426510e+05
# 50%                    1.486380e+05
# 75%                    1.540580e+05
# max                    1.403083e+06

# %%
ft_ecg['ECG impedance short(item207)_clip'] = ft_ecg['ECG impedance short(item207)'].clip(lower=-2)
# Out:
# C:\Users\wangcooper\AppData\Local\Temp\ipykernel_6420\4087045985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ft_ecg['ECG impedance short(item207)_clip'] = ft_ecg['ECG impedance short(item207)'].clip(lower=-2)

# %%
plt.figure(dpi=200)
sns.histplot(ft_ecg, x='ECG impedance short(item207)_clip', hue='Result', hue_order=[True,False])
plt.title('Clip -999 to -2')

#HRM soldering issue? EE comment
# Out:
# Text(0.5, 1.0, 'Clip -999 to -2')

# %%
ft_ecg['ECG impedance short(item207)_clip'].describe()
# Out:
# count    6.280000e+02
# mean     2.023655e+05
# std      2.199587e+05
# min     -2.000000e+00
# 25%      1.426510e+05
# 50%      1.486380e+05
# 75%      1.540580e+05
# max      1.403083e+06
# Name: ECG impedance short(item207)_clip, dtype: float64
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
