# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw = pd.read_excel('PR_PreMP_sonar_Tx_AVG.xlsx')
raw
# Out:
#     SerialNumber       Tx_avg          phase
# 0     3457337174  1151.015625             PR
# 1     3457337175   870.162000             PR
# 2     3457337176   968.853250             PR
# 3     3457337177  1521.156500             PR
# 4     3457337178  1204.363500             PR
# ..           ...          ...            ...
# 405       MP8803   648.443800  PreMP_ReScrew
# 406       MP8931   680.900600  PreMP_ReScrew
# 407       MP8839   858.488900  PreMP_ReScrew
# 408       MP8930   536.490400  PreMP_ReScrew
# 409       MP8885   711.653600  PreMP_ReScrew
#
# [410 rows x 3 columns]

# %%
plt.figure(dpi=150)
sns.violinplot(data=raw, x='phase', y='Tx_avg', bw=0.4, inner='points')
plt.axhline(y=880, ls='--', color='red', lw=1)
plt.text(s = 'PR LSL', y=900, x='PreMP', color='red')
# Out:
# C:\Users\wangcooper\AppData\Local\Temp\ipykernel_3544\1111765141.py:2: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.4`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.violinplot(data=raw, x='phase', y='Tx_avg', bw=0.4, inner='points')
# Text(PreMP, 900, 'PR LSL')
