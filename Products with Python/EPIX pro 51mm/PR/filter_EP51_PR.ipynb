# %%
import pandas as pd

# %%
raw = pd.read_excel('EP51_45degree_PR.xlsx',sheet_name='Test Result')

# %%
raw.sample(3)
# Out:
#      ItemName Type          Process Type  Item              ItemName  \
# 161          18307  General_ECG_Sampling    42   Linearity_01 Result
# 24           17801           Epix_Pro_HT     8  電池電壓|Battery Voltage
# 91           17820       Epix_Pro_ECG_FT   285   ECG impedance short
#
#     Count/Count ESN  Retest%
# 161           10/14    71.43
# 24            7/632     1.11
# 91           96/608    15.79

# %%
ProcessTypeBlackList = 'Pack|Click|RabbitCard|EasyCard|DeleteBundle|ProdScan|FileCopyer'
ItemNameBlackList = 'ESN|Check ProductionMap|Fixture ID'

# %%
def filter(raw):
    return(raw
    .rename(columns = lambda name : name.replace(" ",'').replace('/','').replace('%',''))
    .sort_values('Retest', ascending=False)
    .astype({'ItemNameType':'category','ProcessType':'category','Item':'category','ItemName':'category'})
    .assign(CountESN = lambda df : df.CountCountESN.str.split('/').str[1].astype('int16'))
    .query("~ProcessType.str.contains(@ProcessTypeBlackList) and ~ItemName.str.contains(@ItemNameBlackList)")
    # .CountESN.quantile(0.03)
    .query("CountESN > CountESN.quantile(0.05)")
    .query("Retest >= Retest.mean()")
    # .Retest.mean()
    )
filter(raw)
# Out:
#     ItemNameType            ProcessType Item  \
# 90         17820        Epix_Pro_ECG_FT  293
# 91         17820        Epix_Pro_ECG_FT  285
# 22         17801            Epix_Pro_HT   42
# 47         17802           Epix_Pro_FT1  202
# 92         17820        Epix_Pro_ECG_FT  299
# 48         17802           Epix_Pro_FT1    9
# 72         17803           Epix_Pro_FT2   36
# 204        17798       Epix_Pro_AutoATE  152
# 49         17802           Epix_Pro_FT1   31
# 177        17859        Epix_Pro_ATE_TI   41
# 29          8837         Airtight_table  124
# 73         17803           Epix_Pro_FT2   38
# 50         17802           Epix_Pro_FT1  146
# 51         17802           Epix_Pro_FT1   35
# 52         17802           Epix_Pro_FT1   33
# 23         17801            Epix_Pro_HT   24
# 70         18672           Epix_Pro_PPG  121
# 74         17803           Epix_Pro_FT2   62
# 200        17855       Epix_Pro_ATE_LED    2
# 178        17859        Epix_Pro_ATE_TI   58
# 54         17802           Epix_Pro_FT1  195
# 179        17859        Epix_Pro_ATE_TI    4
# 103        16510        Epix_Pro_51_M_B  202
# 104        16510        Epix_Pro_51_M_B  212
# 226        18547  Epix_Pro_MultiUpdater   26
# 40         17822           Epix_Pro_ALS   19
# 201        17855       Epix_Pro_ATE_LED    1
# 15         17800            Epix_Pro_CT   60
# 205        17798       Epix_Pro_AutoATE    6
# 30          8837         Airtight_table  118
# 206        17798       Epix_Pro_AutoATE   77
# 207        17798       Epix_Pro_AutoATE    7
# 76         17803           Epix_Pro_FT2   32
# 0          17886         Epix_pro_RTESN   64
#
#                                               ItemName CountCountESN  Retest  \
# 90                             ECG RLD 10Hz 500mV Test       115/608   18.91
# 91                                 ECG impedance short        96/608   15.79
# 22                                       GPS_L5 by ref        79/632   12.50
# 47                    GPS L1+L5 (OLED) Value Different        62/615   10.08
# 92                                    ECG 2mv 5Hz Test        59/608    9.70
# 48                                電池電壓|Battery Voltage        57/615    9.27
# 72                Power Box Sampling BL on normal(Avg)        41/607    6.75
# 204                       Low Power Mode Current (AVR)        52/780    6.67
# 49                               GPS_ (L1 + L5) by ref        36/615    5.85
# 177                              Barometer Temperature        46/792    5.81
# 29                                           連續斜率異常_正壓        31/619    5.01
# 73                 ANT_power 2450MHz BY REF (sapphire)        30/607    4.94
# 50                  Internal Light Pollution (ILP) Ch0        30/615    4.88
# 51          GPS L1+L5 (OLED) Value Different (ep51-00)        29/615    4.72
# 52                                 Check Time Zone Map        28/615    4.55
# 23                                         GPS (L1+L5)        27/632    4.27
# 70                   Full Signal Path (FSP) Ch1 stddev        24/576    4.17
# 74     外部電流(反插)|VEXT Current(Reverse) BL&OHR On - EP51        24/607    3.95
# 200                                  White LED Current        29/765    3.79
# 178  D107 – 540nm Brightness (20mA) Measure diff wi...        28/792    3.54
# 54               充電電流(charging)|VEXT Current(charging)        21/615    3.41
# 179                                   USB Connection 1        27/792    3.41
# 103                                    LRA calibration        18/589    3.06
# 104                 (4000Hz) dBSPL+A (beeper loudness)        17/589    2.89
# 226                                   Check Boot Block        22/781    2.82
# 40                 Temperature Sensor Temperature diff        16/615    2.60
# 201                                  NTC (100k//40.2k)        17/765    2.22
# 15                      GPS_ (L1 + L5) by ref for ep47        13/633    2.05
# 205                BAT3.3V開機電流|BAT3.3V startup current        15/780    1.92
# 30                                           連續斜率異常_負壓        11/619    1.78
# 206          手電筒白光電壓100%|Flashlight White voltage 100%        13/780    1.67
# 207              BAT4.45V開機電流|BAT4.45V startup current        12/780    1.54
# 76                         檔案下載測試|(WiFi) Download Test         9/607    1.48
# 0                                        NFC check 檢查          9/635    1.42
#
#      CountESN
# 90        608
# 91        608
# 22        632
# 47        615
# 92        608
# 48        615
# 72        607
# 204       780
# 49        615
# 177       792
# 29        619
# 73        607
# 50        615
# 51        615
# 52        615
# 23        632
# 70        576
# 74        607
# 200       765
# 178       792
# 54        615
# 179       792
# 103       589
# 104       589
# 226       781
# 40        615
# 201       765
# 15        633
# 205       780
# 30        619
# 206       780
# 207       780
# 76        607
# 0         635

# %%
# filter(raw).to_excel('tweak_EP51_PR_45degree.xlsx', index=False)
