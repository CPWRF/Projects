# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('fivethirtyeight')

# %%
df = pd.read_excel('FR965 GPSL1byref.xlsx')

# %%
df.tDateTime = pd.to_datetime(df.tDateTime, utc=True).dt.tz_convert('Asia/Taipei')
df['TestProgramVersion'] = df.ExeInfo.apply(lambda info : info.split('[')[2][:-20])

# %%
df = df[df.Item117St.isin([0,1])]
df
# Out:
#      Reference  ItemNameType      Station  StationID  UserName  SerialNumber  \
# 0    403342963         16619  T1_5PR1FT12          2     22512    3425573553
# 1    403342967         16619  T1_5PR1FT12          1     22512    3425573562
# 2    403342982         16619  T1_4A06CT01          2     22512    3425573535
# 3    403342990         16619  T1_4A06CT01          1     22512    3425573507
# 7    403343602         16619  T1_4A06CT01          2     22512    3425573570
# ..         ...           ...          ...        ...       ...           ...
# 675  404668749         16619  T1_5PR1FT13          2      2454    3425573238
# 676  404668786         16619  T1_5PR1FT13          1      2454    3425573208
# 677  404668956         16619  T1_5PR1FT13          1      2454    3425573269
# 678  404669196         16619  T1_5PR1FT13          1      2454    3425573635
# 679  404669782         16619  T1_5PR1FT13          2      2454    3425573595
#
#                ProductName  Version  \
# ...

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df, x='Item117', hue='Station', alpha=0.5)
plt.axvline(-2, color='red', ls='--')
