# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw = pd.read_excel('LT95_AMOLED.xlsx')

# %%
plt.style.use('fivethirtyeight')

# %%
plt.figure(dpi=200)
sns.lineplot(data=raw, x='Time', y='LT95', hue='Color', palette=['Red','Green','Blue'])
plt.title('RGB LT for AMOLED')
# Out:
# Text(0.5, 1.0, 'RGB LT for AMOLED')
